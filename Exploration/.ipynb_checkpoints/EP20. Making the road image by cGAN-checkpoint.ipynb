# %% [markdown]
# ### 데이터 불러오기

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
# 이미지 확인
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 이미지 크기 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
# 컬러 이미지와 스케치 이미지로 자르기
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    colored = img[:, :w, :] 
    colored = tf.cast(colored, tf.float32)
    sketch = img[:, w:, :] 
    sketch = tf.cast(sketch, tf.float32)
    return normalize(colored), normalize(sketch)

f = data_path + os.listdir(data_path)[1]
colored, sketch = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(colored))
plt.subplot(1,2,2); plt.imshow(denormalize(sketch))

# %%
# Augumentation 적용

from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %%
# 시각화

plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_colored, augmented_sketch = apply_augmentation(colored, sketch)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow.keras import layers, Input, Model
from tensorflow import data

def get_train(img_path):
    colored, sketch = load_img(img_path)
    colored, sketch = apply_augmentation(colored, sketch)
    return colored, sketch

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
colored, sketch = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(colored[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(sketch[0].astype(np.uint8))

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("✅")
# Out:
# ✅

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_24 (EncodeBlock)   (None, 128, 128, 64) 3072        input_5[0][0]
# __________________________________________________________________________________________________
# encode_block_25 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_24[0][0]
# __________________________________________________________________________________________________
# encode_block_26 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_25[0][0]
# __________________________________________________________________________________________________
# encode_block_27 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_26[0][0]
# __________________________________________________________________________________________________
# encode_block_28 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_27[0][0]
# __________________________________________________________________________________________________
# encode_block_29 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_28[0][0]
# __________________________________________________________________________________________________
# encode_block_30 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_29[0][0]
# __________________________________________________________________________________________________
# encode_block_31 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_30[0][0]
# __________________________________________________________________________________________________
# decode_block_21 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_31[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 2, 2, 1024)   0           decode_block_21[0][0]
#                                                                  encode_block_30[0][0]
# __________________________________________________________________________________________________
# decode_block_22 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 4, 4, 1024)   0           decode_block_22[0][0]
#                                                                  encode_block_29[0][0]
# __________________________________________________________________________________________________
# decode_block_23 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_19[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 1024)   0           decode_block_23[0][0]
#                                                                  encode_block_28[0][0]
# __________________________________________________________________________________________________
# decode_block_24 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_20[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 16, 16, 1024) 0           decode_block_24[0][0]
#                                                                  encode_block_27[0][0]
# __________________________________________________________________________________________________
# decode_block_25 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_21[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 32, 32, 512)  0           decode_block_25[0][0]
#                                                                  encode_block_26[0][0]
# __________________________________________________________________________________________________
# decode_block_26 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 64, 64, 256)  0           decode_block_26[0][0]
#                                                                  encode_block_25[0][0]
# __________________________________________________________________________________________________
# decode_block_27 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_23[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 128, 128, 128 0           decode_block_27[0][0]
#                                                                  encode_block_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_31 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_24[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_73 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
Discriminator().get_summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 256, 256, 6)  0           input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# disc_block_20 (DiscBlock)       (None, 128, 128, 64) 6144        concatenate_25[0][0]
# __________________________________________________________________________________________________
# disc_block_21 (DiscBlock)       (None, 64, 64, 128)  131584      disc_block_20[0][0]
# __________________________________________________________________________________________________
# disc_block_22 (DiscBlock)       (None, 32, 32, 256)  525312      disc_block_21[0][0]
# __________________________________________________________________________________________________
# disc_block_23 (DiscBlock)       (None, 31, 31, 512)  2099200     disc_block_22[0][0]
# __________________________________________________________________________________________________
# disc_block_24 (DiscBlock)       (None, 30, 30, 1)    8192        disc_block_23[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 30, 30, 1)    0           disc_block_24[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("✅")
# Out:
# ✅

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %%
EPOCHS = 128

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (colored, sketch) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(colored, sketch)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:1.0331
# L1_loss:0.2947
# Discriminator_loss:1.2549
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.0693
# L1_loss:0.3349
# Discriminator_loss:0.9699
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.3344
# L1_loss:0.3474
# Discriminator_loss:0.8530
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.5004
# L1_loss:0.2474
# Discriminator_loss:0.7054
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.2717
# L1_loss:0.2810
# Discriminator_loss:1.1044
#
# EPOCH[1] - STEP[60]
# Generator_loss:2.1811
# L1_loss:0.2480
# Discriminator_loss:0.4704
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.2540
# L1_loss:0.2692
# Discriminator_loss:0.6062
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.8922
# L1_loss:0.2438
# Discriminator_loss:0.6117
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.2106
# L1_loss:0.2495
# Discriminator_loss:0.8767
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.4014
# L1_loss:0.2257
# Discriminator_loss:0.7055
#
# EPOCH[1] - STEP[110]
# Generator_loss:2.2162
# L1_loss:0.2240
# Discriminator_loss:0.5413
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.3975
# L1_loss:0.2803
# Discriminator_loss:0.4890
#
# EPOCH[1] - STEP[130]
# Generator_loss:2.6176
# L1_loss:0.2241
# Discriminator_loss:0.3618
#
# EPOCH[1] - STEP[140]
# Generator_loss:2.3920
# L1_loss:0.3007
# Discriminator_loss:0.4978
#
# EPOCH[1] - STEP[150]
# Generator_loss:2.0016
# L1_loss:0.2433
# Discriminator_loss:0.6786
#
# EPOCH[1] - STEP[160]
# Generator_loss:2.6615
# L1_loss:0.2169
# Discriminator_loss:0.3445
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.3425
# L1_loss:0.2801
# Discriminator_loss:1.2487
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.5721
# L1_loss:0.2422
# Discriminator_loss:1.0236
#
# EPOCH[1] - STEP[190]
# Generator_loss:1.2197
# L1_loss:0.2157
# Discriminator_loss:0.7297
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.7268
# L1_loss:0.2361
# Discriminator_loss:0.4235
#
# EPOCH[1] - STEP[210]
# Generator_loss:1.4277
# L1_loss:0.2667
# Discriminator_loss:0.5863
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.7073
# L1_loss:0.2068
# Discriminator_loss:0.4410
#
# EPOCH[1] - STEP[230]
# Generator_loss:1.4152
# L1_loss:0.2444
# Discriminator_loss:0.5996
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.8127
# L1_loss:0.2559
# Discriminator_loss:0.6770
#
# EPOCH[1] - STEP[250]
# Generator_loss:2.6284
# L1_loss:0.2552
# Discriminator_loss:0.3307
#
# EPOCH[2] - STEP[10]
# Generator_loss:1.1211
# L1_loss:0.2073
# Discriminator_loss:1.0685
#
# EPOCH[2] - STEP[20]
# Generator_loss:2.0044
# L1_loss:0.2141
# Discriminator_loss:0.8963
#
# EPOCH[2] - STEP[30]
# Generator_loss:2.0923
# L1_loss:0.2324
# Discriminator_loss:0.4737
#
# EPOCH[2] - STEP[40]
# Generator_loss:2.7370
# L1_loss:0.2237
# Discriminator_loss:1.0386
#
# EPOCH[2] - STEP[50]
# Generator_loss:1.3922
# L1_loss:0.2520
# Discriminator_loss:0.5500
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.9511
# L1_loss:0.2436
# Discriminator_loss:0.5140
#
# EPOCH[2] - STEP[70]
# Generator_loss:2.6969
# L1_loss:0.2187
# Discriminator_loss:0.7668
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.6359
# L1_loss:0.1938
# Discriminator_loss:0.8318
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.7329
# L1_loss:0.2198
# Discriminator_loss:0.4903
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.0596
# L1_loss:0.2200
# Discriminator_loss:0.9971
#
# EPOCH[2] - STEP[110]
# Generator_loss:0.9627
# L1_loss:0.2074
# Discriminator_loss:0.8255
#
# EPOCH[2] - STEP[120]
# Generator_loss:2.1917
# L1_loss:0.1927
# Discriminator_loss:0.8384
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.7761
# L1_loss:0.2437
# Discriminator_loss:0.6088
#
# EPOCH[2] - STEP[140]
# Generator_loss:2.0049
# L1_loss:0.2256
# Discriminator_loss:0.3588
#
# EPOCH[2] - STEP[150]
# Generator_loss:2.5811
# L1_loss:0.1935
# Discriminator_loss:0.5440
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.4659
# L1_loss:0.2729
# Discriminator_loss:0.5411
#
# EPOCH[2] - STEP[170]
# Generator_loss:1.5003
# L1_loss:0.2034
# Discriminator_loss:0.4781
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.4190
# L1_loss:0.2259
# Discriminator_loss:0.6819
#
# EPOCH[2] - STEP[190]
# Generator_loss:1.2451
# L1_loss:0.2152
# Discriminator_loss:1.0781
#
# EPOCH[2] - STEP[200]
# Generator_loss:2.3330
# L1_loss:0.1786
# Discriminator_loss:0.3191
#
# EPOCH[2] - STEP[210]
# Generator_loss:2.4385
# L1_loss:0.1998
# Discriminator_loss:0.4971
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.6636
# L1_loss:0.1695
# Discriminator_loss:0.6388
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.7352
# L1_loss:0.1625
# Discriminator_loss:0.7727
#
# EPOCH[2] - STEP[240]
# Generator_loss:2.0921
# L1_loss:0.2153
# Discriminator_loss:0.2583
#
# EPOCH[2] - STEP[250]
# Generator_loss:2.3771
# L1_loss:0.1927
# Discriminator_loss:0.9091
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.3014
# L1_loss:0.2046
# Discriminator_loss:0.5525
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.9359
# L1_loss:0.2483
# Discriminator_loss:0.3496
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.7224
# L1_loss:0.2038
# Discriminator_loss:0.6672
#
# EPOCH[3] - STEP[40]
# Generator_loss:2.3905
# L1_loss:0.2343
# Discriminator_loss:0.3271
#
# EPOCH[3] - STEP[50]
# Generator_loss:2.8282
# L1_loss:0.2251
# Discriminator_loss:0.5334
#
# EPOCH[3] - STEP[60]
# Generator_loss:1.6364
# L1_loss:0.1603
# Discriminator_loss:0.6029
# EPOCH[3] - STEP[70]
# Generator_loss:0.4075
# L1_loss:0.1866
# Discriminator_loss:1.5698
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.8621
# L1_loss:0.1942
# Discriminator_loss:1.4179
#
# EPOCH[3] - STEP[90]
# Generator_loss:0.7831
# L1_loss:0.2050
# Discriminator_loss:1.1611
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.0326
# L1_loss:0.1851
# Discriminator_loss:0.7705
#
# EPOCH[3] - STEP[110]
# Generator_loss:2.9495
# L1_loss:0.1820
# Discriminator_loss:0.5086
#
# EPOCH[3] - STEP[120]
# Generator_loss:2.3926
# L1_loss:0.1858
# Discriminator_loss:0.4264
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.0997
# L1_loss:0.2034
# Discriminator_loss:0.7851
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.7205
# L1_loss:0.2124
# Discriminator_loss:0.5694
#
# EPOCH[3] - STEP[150]
# Generator_loss:2.3736
# L1_loss:0.1930
# Discriminator_loss:0.5100
#
# EPOCH[3] - STEP[160]
# Generator_loss:0.9270
# L1_loss:0.1741
# Discriminator_loss:0.9443
#
# EPOCH[3] - STEP[170]
# Generator_loss:1.7450
# L1_loss:0.1824
# Discriminator_loss:0.6295
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.0179
# L1_loss:0.2470
# Discriminator_loss:0.7936
#
# EPOCH[3] - STEP[190]
# Generator_loss:1.6238
# L1_loss:0.1686
# Discriminator_loss:0.9642
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.5424
# L1_loss:0.1558
# Discriminator_loss:0.8803
#
# EPOCH[3] - STEP[210]
# Generator_loss:0.6787
# L1_loss:0.2129
# Discriminator_loss:0.8583
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.5422
# L1_loss:0.2237
# Discriminator_loss:0.5136
#
# EPOCH[3] - STEP[230]
# Generator_loss:1.5751
# L1_loss:0.2258
# Discriminator_loss:0.5962
#
# EPOCH[3] - STEP[240]
# Generator_loss:2.3045
# L1_loss:0.1942
# Discriminator_loss:0.7927
#
# EPOCH[3] - STEP[250]
# Generator_loss:2.1455
# L1_loss:0.2195
# Discriminator_loss:1.6879
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.5122
# L1_loss:0.2081
# Discriminator_loss:0.6294
#
# EPOCH[4] - STEP[20]
# Generator_loss:1.7428
# L1_loss:0.2565
# Discriminator_loss:0.5333
#
# EPOCH[4] - STEP[30]
# Generator_loss:3.0913
# L1_loss:0.2425
# Discriminator_loss:0.3490
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.8992
# L1_loss:0.1895
# Discriminator_loss:0.5640
#
# EPOCH[4] - STEP[50]
# Generator_loss:3.1549
# L1_loss:0.2238
# Discriminator_loss:1.9010
#
# EPOCH[4] - STEP[60]
# Generator_loss:2.2371
# L1_loss:0.2001
# Discriminator_loss:0.3180
#
# EPOCH[4] - STEP[70]
# Generator_loss:1.0203
# L1_loss:0.2040
# Discriminator_loss:0.7871
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.6222
# L1_loss:0.2306
# Discriminator_loss:0.4195
#
# EPOCH[4] - STEP[90]
# Generator_loss:0.3617
# L1_loss:0.2353
# Discriminator_loss:1.5226
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.2350
# L1_loss:0.2013
# Discriminator_loss:0.6121
#
# EPOCH[4] - STEP[110]
# Generator_loss:2.3165
# L1_loss:0.2064
# Discriminator_loss:1.3264
#
# EPOCH[4] - STEP[120]
# Generator_loss:0.4711
# L1_loss:0.2040
# Discriminator_loss:1.4864
#
# EPOCH[4] - STEP[130]
# Generator_loss:2.6921
# L1_loss:0.2033
# Discriminator_loss:0.9326
#
# EPOCH[4] - STEP[140]
# Generator_loss:1.0803
# L1_loss:0.1934
# Discriminator_loss:0.8238
#
# EPOCH[4] - STEP[150]
# Generator_loss:1.7873
# L1_loss:0.1859
# Discriminator_loss:0.9105
#
# EPOCH[4] - STEP[160]
# Generator_loss:3.8821
# L1_loss:0.2209
# Discriminator_loss:1.1114
#
# EPOCH[4] - STEP[170]
# Generator_loss:3.5448
# L1_loss:0.2014
# Discriminator_loss:1.2554
#
# EPOCH[4] - STEP[180]
# Generator_loss:2.4064
# L1_loss:0.2136
# Discriminator_loss:0.3834
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.6823
# L1_loss:0.1718
# Discriminator_loss:1.0283
#
# EPOCH[4] - STEP[200]
# Generator_loss:2.0617
# L1_loss:0.1597
# Discriminator_loss:0.8632
#
# EPOCH[4] - STEP[210]
# Generator_loss:0.8278
# L1_loss:0.1922
# Discriminator_loss:1.0371
#
# EPOCH[4] - STEP[220]
# Generator_loss:0.9419
# L1_loss:0.2204
# Discriminator_loss:0.8236
#
# EPOCH[4] - STEP[230]
# Generator_loss:2.1292
# L1_loss:0.1806
# Discriminator_loss:0.6505
#
# EPOCH[4] - STEP[240]
# Generator_loss:0.6647
# L1_loss:0.1892
# Discriminator_loss:1.1443
#
# EPOCH[4] - STEP[250]
# Generator_loss:2.4598
# L1_loss:0.1771
# Discriminator_loss:0.6241
#
# EPOCH[5] - STEP[10]
# Generator_loss:2.5514
# L1_loss:0.2179
# Discriminator_loss:0.8312
#
# EPOCH[5] - STEP[20]
# Generator_loss:2.7215
# L1_loss:0.2098
# Discriminator_loss:0.2400
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.2022
# L1_loss:0.1817
# Discriminator_loss:0.5485
#
# EPOCH[5] - STEP[40]
# Generator_loss:0.8853
# L1_loss:0.1902
# Discriminator_loss:0.8728
#
# EPOCH[5] - STEP[50]
# Generator_loss:0.4376
# L1_loss:0.2274
# Discriminator_loss:1.2812
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.7126
# L1_loss:0.2033
# Discriminator_loss:0.9117
#
# EPOCH[5] - STEP[70]
# Generator_loss:1.7453
# L1_loss:0.2311
# Discriminator_loss:1.1004
#
# EPOCH[5] - STEP[80]
# Generator_loss:3.1094
# L1_loss:0.1475
# Discriminator_loss:1.4533
#
# EPOCH[5] - STEP[90]
# Generator_loss:2.9338
# L1_loss:0.2073
# Discriminator_loss:0.4517
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.4940
# L1_loss:0.1748
# Discriminator_loss:0.6454
#
# EPOCH[5] - STEP[110]
# Generator_loss:2.4420
# L1_loss:0.2160
# Discriminator_loss:1.1166
#
# EPOCH[5] - STEP[120]
# Generator_loss:2.3978
# L1_loss:0.2051
# Discriminator_loss:0.2555
# EPOCH[5] - STEP[130]
# Generator_loss:1.3989
# L1_loss:0.1726
# Discriminator_loss:0.8303
#
# EPOCH[5] - STEP[140]
# Generator_loss:0.1766
# L1_loss:0.1853
# Discriminator_loss:2.2569
#
# EPOCH[5] - STEP[150]
# Generator_loss:0.5365
# L1_loss:0.2365
# Discriminator_loss:1.3087
#
# EPOCH[5] - STEP[160]
# Generator_loss:0.9578
# L1_loss:0.1857
# Discriminator_loss:0.8991
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.2002
# L1_loss:0.1905
# Discriminator_loss:0.3659
#
# EPOCH[5] - STEP[180]
# Generator_loss:2.9056
# L1_loss:0.1861
# Discriminator_loss:2.2761
#
# EPOCH[5] - STEP[190]
# Generator_loss:1.2315
# L1_loss:0.1896
# Discriminator_loss:0.6375
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.0028
# L1_loss:0.1664
# Discriminator_loss:0.7856
#
# EPOCH[5] - STEP[210]
# Generator_loss:0.7563
# L1_loss:0.2103
# Discriminator_loss:0.8817
#
# EPOCH[5] - STEP[220]
# Generator_loss:2.0764
# L1_loss:0.1508
# Discriminator_loss:0.9064
#
# EPOCH[5] - STEP[230]
# Generator_loss:2.0222
# L1_loss:0.1808
# Discriminator_loss:0.8406
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.6989
# L1_loss:0.1872
# Discriminator_loss:0.7476
#
# EPOCH[5] - STEP[250]
# Generator_loss:2.4414
# L1_loss:0.1717
# Discriminator_loss:2.1558
#
# EPOCH[6] - STEP[10]
# Generator_loss:0.9805
# L1_loss:0.1775
# Discriminator_loss:1.0137
#
# EPOCH[6] - STEP[20]
# Generator_loss:2.3991
# L1_loss:0.2110
# Discriminator_loss:0.7603
#
# EPOCH[6] - STEP[30]
# Generator_loss:2.9216
# L1_loss:0.1823
# Discriminator_loss:1.6289
#
# EPOCH[6] - STEP[40]
# Generator_loss:1.1334
# L1_loss:0.1740
# Discriminator_loss:0.7283
#
# EPOCH[6] - STEP[50]
# Generator_loss:2.8512
# L1_loss:0.1696
# Discriminator_loss:0.6235
#
# EPOCH[6] - STEP[60]
# Generator_loss:3.0255
# L1_loss:0.1703
# Discriminator_loss:2.3358
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.5880
# L1_loss:0.1652
# Discriminator_loss:0.9935
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.1869
# L1_loss:0.1721
# Discriminator_loss:0.6317
#
# EPOCH[6] - STEP[90]
# Generator_loss:2.6219
# L1_loss:0.1679
# Discriminator_loss:1.3959
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.0587
# L1_loss:0.2217
# Discriminator_loss:0.6442
#
# EPOCH[6] - STEP[110]
# Generator_loss:2.3681
# L1_loss:0.2489
# Discriminator_loss:0.4027
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.6357
# L1_loss:0.2115
# Discriminator_loss:0.5364
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.1707
# L1_loss:0.1759
# Discriminator_loss:0.9451
#
# EPOCH[6] - STEP[140]
# Generator_loss:2.1276
# L1_loss:0.2035
# Discriminator_loss:1.5556
#
# EPOCH[6] - STEP[150]
# Generator_loss:1.2413
# L1_loss:0.1875
# Discriminator_loss:0.5699
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.6375
# L1_loss:0.1797
# Discriminator_loss:0.5175
#
# EPOCH[6] - STEP[170]
# Generator_loss:1.2562
# L1_loss:0.2071
# Discriminator_loss:0.4635
#
# EPOCH[6] - STEP[180]
# Generator_loss:0.6334
# L1_loss:0.1941
# Discriminator_loss:1.3132
#
# EPOCH[6] - STEP[190]
# Generator_loss:2.6331
# L1_loss:0.1576
# Discriminator_loss:1.4200
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.9571
# L1_loss:0.1955
# Discriminator_loss:0.7157
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.6018
# L1_loss:0.2058
# Discriminator_loss:0.4964
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.0642
# L1_loss:0.2159
# Discriminator_loss:0.9085
#
# EPOCH[6] - STEP[230]
# Generator_loss:1.8654
# L1_loss:0.1534
# Discriminator_loss:0.3273
#
# EPOCH[6] - STEP[240]
# Generator_loss:3.6543
# L1_loss:0.1858
# Discriminator_loss:1.3018
#
# EPOCH[6] - STEP[250]
# Generator_loss:0.6474
# L1_loss:0.1885
# Discriminator_loss:1.2133
#
# EPOCH[7] - STEP[10]
# Generator_loss:3.7045
# L1_loss:0.1827
# Discriminator_loss:0.9022
#
# EPOCH[7] - STEP[20]
# Generator_loss:1.9293
# L1_loss:0.1510
# Discriminator_loss:1.1691
#
# EPOCH[7] - STEP[30]
# Generator_loss:1.2627
# L1_loss:0.2056
# Discriminator_loss:0.6857
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.7128
# L1_loss:0.1785
# Discriminator_loss:0.8980
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.7398
# L1_loss:0.1761
# Discriminator_loss:1.6940
#
# EPOCH[7] - STEP[60]
# Generator_loss:1.0246
# L1_loss:0.1991
# Discriminator_loss:0.7925
#
# EPOCH[7] - STEP[70]
# Generator_loss:2.3445
# L1_loss:0.2008
# Discriminator_loss:0.5854
#
# EPOCH[7] - STEP[80]
# Generator_loss:2.2291
# L1_loss:0.1714
# Discriminator_loss:0.3314
#
# EPOCH[7] - STEP[90]
# Generator_loss:1.0387
# L1_loss:0.1723
# Discriminator_loss:0.6109
#
# EPOCH[7] - STEP[100]
# Generator_loss:0.7491
# L1_loss:0.2194
# Discriminator_loss:0.8062
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.1260
# L1_loss:0.1507
# Discriminator_loss:0.5160
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.8557
# L1_loss:0.2084
# Discriminator_loss:0.3466
#
# EPOCH[7] - STEP[130]
# Generator_loss:0.5229
# L1_loss:0.1719
# Discriminator_loss:1.3544
#
# EPOCH[7] - STEP[140]
# Generator_loss:2.2041
# L1_loss:0.2149
# Discriminator_loss:0.5907
#
# EPOCH[7] - STEP[150]
# Generator_loss:2.7117
# L1_loss:0.1826
# Discriminator_loss:0.4519
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.8728
# L1_loss:0.1400
# Discriminator_loss:1.7140
#
# EPOCH[7] - STEP[170]
# Generator_loss:0.5871
# L1_loss:0.2529
# Discriminator_loss:0.9734
#
# EPOCH[7] - STEP[180]
# Generator_loss:2.3549
# L1_loss:0.2316
# Discriminator_loss:0.3217
# EPOCH[7] - STEP[190]
# Generator_loss:2.5670
# L1_loss:0.2034
# Discriminator_loss:0.4877
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.5977
# L1_loss:0.2211
# Discriminator_loss:0.3641
#
# EPOCH[7] - STEP[210]
# Generator_loss:1.2913
# L1_loss:0.1495
# Discriminator_loss:0.9036
#
# EPOCH[7] - STEP[220]
# Generator_loss:2.1167
# L1_loss:0.1974
# Discriminator_loss:0.3938
#
# EPOCH[7] - STEP[230]
# Generator_loss:1.1967
# L1_loss:0.1410
# Discriminator_loss:1.7030
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.4137
# L1_loss:0.2215
# Discriminator_loss:0.6940
#
# EPOCH[7] - STEP[250]
# Generator_loss:3.6468
# L1_loss:0.1604
# Discriminator_loss:0.8550
#
# EPOCH[8] - STEP[10]
# Generator_loss:2.1718
# L1_loss:0.1638
# Discriminator_loss:0.5429
#
# EPOCH[8] - STEP[20]
# Generator_loss:0.7218
# L1_loss:0.2054
# Discriminator_loss:1.0495
#
# EPOCH[8] - STEP[30]
# Generator_loss:2.0979
# L1_loss:0.2063
# Discriminator_loss:0.5173
#
# EPOCH[8] - STEP[40]
# Generator_loss:1.5360
# L1_loss:0.1659
# Discriminator_loss:0.6989
#
# EPOCH[8] - STEP[50]
# Generator_loss:2.4734
# L1_loss:0.1757
# Discriminator_loss:1.1944
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.6307
# L1_loss:0.1906
# Discriminator_loss:0.5713
#
# EPOCH[8] - STEP[70]
# Generator_loss:2.4979
# L1_loss:0.2392
# Discriminator_loss:0.4081
#
# EPOCH[8] - STEP[80]
# Generator_loss:2.6176
# L1_loss:0.2009
# Discriminator_loss:0.3537
#
# EPOCH[8] - STEP[90]
# Generator_loss:3.9055
# L1_loss:0.1632
# Discriminator_loss:1.6922
#
# EPOCH[8] - STEP[100]
# Generator_loss:1.9881
# L1_loss:0.1654
# Discriminator_loss:0.5103
#
# EPOCH[8] - STEP[110]
# Generator_loss:1.8414
# L1_loss:0.1634
# Discriminator_loss:0.4508
#
# EPOCH[8] - STEP[120]
# Generator_loss:1.1780
# L1_loss:0.1756
# Discriminator_loss:1.1096
#
# EPOCH[8] - STEP[130]
# Generator_loss:1.5328
# L1_loss:0.1751
# Discriminator_loss:0.5674
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.4393
# L1_loss:0.2055
# Discriminator_loss:0.4872
#
# EPOCH[8] - STEP[150]
# Generator_loss:0.3618
# L1_loss:0.1720
# Discriminator_loss:1.7404
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.7073
# L1_loss:0.1572
# Discriminator_loss:0.5244
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.8632
# L1_loss:0.2065
# Discriminator_loss:0.3528
#
# EPOCH[8] - STEP[180]
# Generator_loss:1.1377
# L1_loss:0.1889
# Discriminator_loss:0.5528
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.8795
# L1_loss:0.2184
# Discriminator_loss:0.5561
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.9435
# L1_loss:0.1731
# Discriminator_loss:1.1078
#
# EPOCH[8] - STEP[210]
# Generator_loss:2.8816
# L1_loss:0.1680
# Discriminator_loss:1.6411
#
# EPOCH[8] - STEP[220]
# Generator_loss:3.6823
# L1_loss:0.1937
# Discriminator_loss:1.5926
#
# EPOCH[8] - STEP[230]
# Generator_loss:1.3573
# L1_loss:0.1708
# Discriminator_loss:0.5882
#
# EPOCH[8] - STEP[240]
# Generator_loss:1.7032
# L1_loss:0.1720
# Discriminator_loss:0.5482
#
# EPOCH[8] - STEP[250]
# Generator_loss:1.7704
# L1_loss:0.2163
# Discriminator_loss:0.5288
#
# EPOCH[9] - STEP[10]
# Generator_loss:0.8290
# L1_loss:0.1647
# Discriminator_loss:1.0906
#
# EPOCH[9] - STEP[20]
# Generator_loss:2.2480
# L1_loss:0.2116
# Discriminator_loss:0.4060
#
# EPOCH[9] - STEP[30]
# Generator_loss:0.3768
# L1_loss:0.1994
# Discriminator_loss:1.4724
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.5459
# L1_loss:0.1779
# Discriminator_loss:0.4491
#
# EPOCH[9] - STEP[50]
# Generator_loss:1.9328
# L1_loss:0.1486
# Discriminator_loss:0.5592
#
# EPOCH[9] - STEP[60]
# Generator_loss:1.6493
# L1_loss:0.1561
# Discriminator_loss:0.7058
#
# EPOCH[9] - STEP[70]
# Generator_loss:2.2535
# L1_loss:0.2112
# Discriminator_loss:0.6472
#
# EPOCH[9] - STEP[80]
# Generator_loss:2.2487
# L1_loss:0.2067
# Discriminator_loss:0.7143
#
# EPOCH[9] - STEP[90]
# Generator_loss:2.3990
# L1_loss:0.2058
# Discriminator_loss:0.2752
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.5102
# L1_loss:0.1705
# Discriminator_loss:1.5628
#
# EPOCH[9] - STEP[110]
# Generator_loss:2.5638
# L1_loss:0.1853
# Discriminator_loss:0.3886
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.4476
# L1_loss:0.1804
# Discriminator_loss:0.6942
#
# EPOCH[9] - STEP[130]
# Generator_loss:0.8079
# L1_loss:0.1791
# Discriminator_loss:0.8338
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.8462
# L1_loss:0.1880
# Discriminator_loss:0.5607
#
# EPOCH[9] - STEP[150]
# Generator_loss:2.6200
# L1_loss:0.1976
# Discriminator_loss:0.5886
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.3925
# L1_loss:0.2156
# Discriminator_loss:0.4197
#
# EPOCH[9] - STEP[170]
# Generator_loss:2.6379
# L1_loss:0.1971
# Discriminator_loss:1.4620
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.7603
# L1_loss:0.1759
# Discriminator_loss:0.7899
#
# EPOCH[9] - STEP[190]
# Generator_loss:2.1760
# L1_loss:0.1764
# Discriminator_loss:0.4805
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.1115
# L1_loss:0.1424
# Discriminator_loss:0.6124
#
# EPOCH[9] - STEP[210]
# Generator_loss:2.0321
# L1_loss:0.1920
# Discriminator_loss:0.2671
#
# EPOCH[9] - STEP[220]
# Generator_loss:2.2862
# L1_loss:0.2738
# Discriminator_loss:0.2440
#
# EPOCH[9] - STEP[230]
# Generator_loss:2.5176
# L1_loss:0.1677
# Discriminator_loss:1.2110
#
# EPOCH[9] - STEP[240]
# Generator_loss:1.5390
# L1_loss:0.1740
# Discriminator_loss:0.6978
# EPOCH[9] - STEP[250]
# Generator_loss:1.8941
# L1_loss:0.1691
# Discriminator_loss:0.3129
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.9880
# L1_loss:0.1962
# Discriminator_loss:0.9756
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.9280
# L1_loss:0.1530
# Discriminator_loss:1.0148
#
# EPOCH[10] - STEP[30]
# Generator_loss:0.9401
# L1_loss:0.1479
# Discriminator_loss:0.6443
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.3988
# L1_loss:0.2079
# Discriminator_loss:0.7496
#
# EPOCH[10] - STEP[50]
# Generator_loss:0.5632
# L1_loss:0.2245
# Discriminator_loss:1.0375
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.8874
# L1_loss:0.1758
# Discriminator_loss:0.3841
#
# EPOCH[10] - STEP[70]
# Generator_loss:1.2311
# L1_loss:0.1997
# Discriminator_loss:0.5242
#
# EPOCH[10] - STEP[80]
# Generator_loss:1.7668
# L1_loss:0.1605
# Discriminator_loss:0.9636
#
# EPOCH[10] - STEP[90]
# Generator_loss:1.5878
# L1_loss:0.1665
# Discriminator_loss:0.3742
#
# EPOCH[10] - STEP[100]
# Generator_loss:1.8666
# L1_loss:0.1881
# Discriminator_loss:0.7220
#
# EPOCH[10] - STEP[110]
# Generator_loss:1.9792
# L1_loss:0.1782
# Discriminator_loss:0.3521
#
# EPOCH[10] - STEP[120]
# Generator_loss:3.4707
# L1_loss:0.1713
# Discriminator_loss:1.5935
#
# EPOCH[10] - STEP[130]
# Generator_loss:2.1145
# L1_loss:0.2275
# Discriminator_loss:0.5897
#
# EPOCH[10] - STEP[140]
# Generator_loss:0.7807
# L1_loss:0.2657
# Discriminator_loss:0.7939
#
# EPOCH[10] - STEP[150]
# Generator_loss:1.7449
# L1_loss:0.1543
# Discriminator_loss:0.6940
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.0868
# L1_loss:0.1806
# Discriminator_loss:0.6957
#
# EPOCH[10] - STEP[170]
# Generator_loss:2.9126
# L1_loss:0.1823
# Discriminator_loss:1.7215
#
# EPOCH[10] - STEP[180]
# Generator_loss:1.4923
# L1_loss:0.1772
# Discriminator_loss:0.4901
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.7425
# L1_loss:0.1655
# Discriminator_loss:0.8055
#
# EPOCH[10] - STEP[200]
# Generator_loss:2.2170
# L1_loss:0.1555
# Discriminator_loss:0.4537
#
# EPOCH[10] - STEP[210]
# Generator_loss:1.4810
# L1_loss:0.1930
# Discriminator_loss:0.6214
#
# EPOCH[10] - STEP[220]
# Generator_loss:1.1619
# L1_loss:0.2285
# Discriminator_loss:0.6076
#
# EPOCH[10] - STEP[230]
# Generator_loss:1.1331
# L1_loss:0.1806
# Discriminator_loss:0.6412
#
# EPOCH[10] - STEP[240]
# Generator_loss:2.8608
# L1_loss:0.1649
# Discriminator_loss:0.7800
#
# EPOCH[10] - STEP[250]
# Generator_loss:1.9700
# L1_loss:0.1604
# Discriminator_loss:0.8559
#
# EPOCH[11] - STEP[10]
# Generator_loss:1.2172
# L1_loss:0.1473
# Discriminator_loss:0.9852
#
# EPOCH[11] - STEP[20]
# Generator_loss:1.8721
# L1_loss:0.2100
# Discriminator_loss:0.3437
#
# EPOCH[11] - STEP[30]
# Generator_loss:2.3923
# L1_loss:0.1676
# Discriminator_loss:1.0932
#
# EPOCH[11] - STEP[40]
# Generator_loss:2.1472
# L1_loss:0.1454
# Discriminator_loss:0.9677
#
# EPOCH[11] - STEP[50]
# Generator_loss:2.2712
# L1_loss:0.1825
# Discriminator_loss:0.2968
#
# EPOCH[11] - STEP[60]
# Generator_loss:2.1475
# L1_loss:0.1707
# Discriminator_loss:1.0608
#
# EPOCH[11] - STEP[70]
# Generator_loss:1.6169
# L1_loss:0.1653
# Discriminator_loss:1.6475
#
# EPOCH[11] - STEP[80]
# Generator_loss:1.6992
# L1_loss:0.1722
# Discriminator_loss:0.3660
#
# EPOCH[11] - STEP[90]
# Generator_loss:1.4627
# L1_loss:0.1628
# Discriminator_loss:0.7366
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.0218
# L1_loss:0.2664
# Discriminator_loss:0.5555
#
# EPOCH[11] - STEP[110]
# Generator_loss:2.2978
# L1_loss:0.2116
# Discriminator_loss:0.5986
#
# EPOCH[11] - STEP[120]
# Generator_loss:2.3208
# L1_loss:0.1630
# Discriminator_loss:0.4263
#
# EPOCH[11] - STEP[130]
# Generator_loss:0.9848
# L1_loss:0.2000
# Discriminator_loss:0.6030
#
# EPOCH[11] - STEP[140]
# Generator_loss:0.9822
# L1_loss:0.2248
# Discriminator_loss:0.8386
#
# EPOCH[11] - STEP[150]
# Generator_loss:1.7017
# L1_loss:0.2121
# Discriminator_loss:0.3120
#
# EPOCH[11] - STEP[160]
# Generator_loss:3.7578
# L1_loss:0.1591
# Discriminator_loss:0.8910
#
# EPOCH[11] - STEP[170]
# Generator_loss:1.5308
# L1_loss:0.1677
# Discriminator_loss:0.7860
#
# EPOCH[11] - STEP[180]
# Generator_loss:2.0507
# L1_loss:0.1524
# Discriminator_loss:1.3075
#
# EPOCH[11] - STEP[190]
# Generator_loss:2.7584
# L1_loss:0.2335
# Discriminator_loss:0.1876
#
# EPOCH[11] - STEP[200]
# Generator_loss:4.6950
# L1_loss:0.1561
# Discriminator_loss:1.2898
#
# EPOCH[11] - STEP[210]
# Generator_loss:0.6666
# L1_loss:0.1890
# Discriminator_loss:0.9730
#
# EPOCH[11] - STEP[220]
# Generator_loss:0.8067
# L1_loss:0.1689
# Discriminator_loss:1.0510
#
# EPOCH[11] - STEP[230]
# Generator_loss:2.3886
# L1_loss:0.1635
# Discriminator_loss:0.5320
#
# EPOCH[11] - STEP[240]
# Generator_loss:0.7198
# L1_loss:0.1660
# Discriminator_loss:1.0756
#
# EPOCH[11] - STEP[250]
# Generator_loss:1.1888
# L1_loss:0.1897
# Discriminator_loss:0.5121
#
# EPOCH[12] - STEP[10]
# Generator_loss:1.8798
# L1_loss:0.1549
# Discriminator_loss:0.7905
#
# EPOCH[12] - STEP[20]
# Generator_loss:2.1046
# L1_loss:0.1626
# Discriminator_loss:0.9392
#
# EPOCH[12] - STEP[30]
# Generator_loss:2.7519
# L1_loss:0.1519
# Discriminator_loss:1.7088
#
# EPOCH[12] - STEP[40]
# Generator_loss:2.8569
# L1_loss:0.1841
# Discriminator_loss:0.1865
#
# EPOCH[12] - STEP[50]
# Generator_loss:1.4806
# L1_loss:0.1533
# Discriminator_loss:0.5033
# EPOCH[12] - STEP[60]
# Generator_loss:2.6992
# L1_loss:0.1589
# Discriminator_loss:1.0934
#
# EPOCH[12] - STEP[70]
# Generator_loss:1.3579
# L1_loss:0.1637
# Discriminator_loss:0.8898
#
# EPOCH[12] - STEP[80]
# Generator_loss:2.0454
# L1_loss:0.1759
# Discriminator_loss:0.9996
#
# EPOCH[12] - STEP[90]
# Generator_loss:0.5043
# L1_loss:0.1723
# Discriminator_loss:1.1633
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.3636
# L1_loss:0.1791
# Discriminator_loss:0.4514
#
# EPOCH[12] - STEP[110]
# Generator_loss:2.4569
# L1_loss:0.1786
# Discriminator_loss:0.6967
#
# EPOCH[12] - STEP[120]
# Generator_loss:0.7621
# L1_loss:0.2027
# Discriminator_loss:0.9940
#
# EPOCH[12] - STEP[130]
# Generator_loss:1.4047
# L1_loss:0.1597
# Discriminator_loss:0.6386
#
# EPOCH[12] - STEP[140]
# Generator_loss:1.8953
# L1_loss:0.1983
# Discriminator_loss:0.5926
#
# EPOCH[12] - STEP[150]
# Generator_loss:3.5865
# L1_loss:0.1786
# Discriminator_loss:2.1530
#
# EPOCH[12] - STEP[160]
# Generator_loss:1.2887
# L1_loss:0.1927
# Discriminator_loss:0.4840
#
# EPOCH[12] - STEP[170]
# Generator_loss:0.8432
# L1_loss:0.2106
# Discriminator_loss:1.2019
#
# EPOCH[12] - STEP[180]
# Generator_loss:2.2795
# L1_loss:0.2084
# Discriminator_loss:0.8384
#
# EPOCH[12] - STEP[190]
# Generator_loss:1.9683
# L1_loss:0.1706
# Discriminator_loss:0.6266
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.0739
# L1_loss:0.1673
# Discriminator_loss:1.1828
#
# EPOCH[12] - STEP[210]
# Generator_loss:3.1104
# L1_loss:0.1752
# Discriminator_loss:0.2870
#
# EPOCH[12] - STEP[220]
# Generator_loss:1.8468
# L1_loss:0.1695
# Discriminator_loss:1.0081
#
# EPOCH[12] - STEP[230]
# Generator_loss:1.4355
# L1_loss:0.1977
# Discriminator_loss:1.0577
#
# EPOCH[12] - STEP[240]
# Generator_loss:2.0150
# L1_loss:0.1814
# Discriminator_loss:0.7651
#
# EPOCH[12] - STEP[250]
# Generator_loss:2.1594
# L1_loss:0.1594
# Discriminator_loss:0.4068
#
# EPOCH[13] - STEP[10]
# Generator_loss:1.2537
# L1_loss:0.1595
# Discriminator_loss:0.6993
#
# EPOCH[13] - STEP[20]
# Generator_loss:2.5841
# L1_loss:0.1938
# Discriminator_loss:0.7902
#
# EPOCH[13] - STEP[30]
# Generator_loss:0.7190
# L1_loss:0.1596
# Discriminator_loss:0.8871
#
# EPOCH[13] - STEP[40]
# Generator_loss:2.1546
# L1_loss:0.1433
# Discriminator_loss:0.4628
#
# EPOCH[13] - STEP[50]
# Generator_loss:1.0364
# L1_loss:0.1676
# Discriminator_loss:0.7898
#
# EPOCH[13] - STEP[60]
# Generator_loss:0.2794
# L1_loss:0.1459
# Discriminator_loss:1.6220
#
# EPOCH[13] - STEP[70]
# Generator_loss:1.9866
# L1_loss:0.2034
# Discriminator_loss:0.7022
#
# EPOCH[13] - STEP[80]
# Generator_loss:0.9869
# L1_loss:0.1808
# Discriminator_loss:0.8030
#
# EPOCH[13] - STEP[90]
# Generator_loss:0.5564
# L1_loss:0.1659
# Discriminator_loss:1.0072
#
# EPOCH[13] - STEP[100]
# Generator_loss:2.9293
# L1_loss:0.1611
# Discriminator_loss:1.5212
#
# EPOCH[13] - STEP[110]
# Generator_loss:2.4880
# L1_loss:0.1878
# Discriminator_loss:0.3679
#
# EPOCH[13] - STEP[120]
# Generator_loss:2.2956
# L1_loss:0.1944
# Discriminator_loss:0.4989
#
# EPOCH[13] - STEP[130]
# Generator_loss:1.1607
# L1_loss:0.1847
# Discriminator_loss:0.7852
#
# EPOCH[13] - STEP[140]
# Generator_loss:0.1934
# L1_loss:0.1945
# Discriminator_loss:2.3273
#
# EPOCH[13] - STEP[150]
# Generator_loss:1.1362
# L1_loss:0.1600
# Discriminator_loss:0.6776
#
# EPOCH[13] - STEP[160]
# Generator_loss:2.3260
# L1_loss:0.1650
# Discriminator_loss:0.7627
#
# EPOCH[13] - STEP[170]
# Generator_loss:1.3965
# L1_loss:0.1669
# Discriminator_loss:1.3390
#
# EPOCH[13] - STEP[180]
# Generator_loss:2.4508
# L1_loss:0.2161
# Discriminator_loss:0.4750
#
# EPOCH[13] - STEP[190]
# Generator_loss:1.9082
# L1_loss:0.1494
# Discriminator_loss:0.4696
#
# EPOCH[13] - STEP[200]
# Generator_loss:2.8061
# L1_loss:0.1776
# Discriminator_loss:0.3032
#
# EPOCH[13] - STEP[210]
# Generator_loss:1.2660
# L1_loss:0.1565
# Discriminator_loss:1.8725
#
# EPOCH[13] - STEP[220]
# Generator_loss:2.2952
# L1_loss:0.1797
# Discriminator_loss:0.5444
#
# EPOCH[13] - STEP[230]
# Generator_loss:1.6331
# L1_loss:0.2070
# Discriminator_loss:0.6817
#
# EPOCH[13] - STEP[240]
# Generator_loss:1.7020
# L1_loss:0.2142
# Discriminator_loss:0.2695
#
# EPOCH[13] - STEP[250]
# ...
# Generator_loss:6.6055
# L1_loss:0.1247
# Discriminator_loss:0.7238
#
# EPOCH[124] - STEP[200]
# Generator_loss:6.9197
# L1_loss:0.1276
# Discriminator_loss:0.0218
#
# EPOCH[124] - STEP[210]
# Generator_loss:1.9960
# L1_loss:0.1428
# Discriminator_loss:0.3686
#
# EPOCH[124] - STEP[220]
# Generator_loss:1.9506
# L1_loss:0.1251
# Discriminator_loss:0.3181
#
# EPOCH[124] - STEP[230]
# Generator_loss:4.3489
# L1_loss:0.1109
# Discriminator_loss:0.0355
#
# EPOCH[124] - STEP[240]
# Generator_loss:1.7032
# L1_loss:0.1609
# Discriminator_loss:0.6803
#
# EPOCH[124] - STEP[250]
# Generator_loss:4.1241
# L1_loss:0.1534
# Discriminator_loss:0.0992
#
# EPOCH[125] - STEP[10]
# Generator_loss:4.6417
# L1_loss:0.1289
# Discriminator_loss:0.4524
#
# EPOCH[125] - STEP[20]
# Generator_loss:2.4921
# L1_loss:0.1597
# Discriminator_loss:0.2686
#
# EPOCH[125] - STEP[30]
# Generator_loss:2.9474
# L1_loss:0.1229
# Discriminator_loss:0.1456
#
# EPOCH[125] - STEP[40]
# Generator_loss:5.9825
# L1_loss:0.1384
# Discriminator_loss:0.1540
#
# EPOCH[125] - STEP[50]
# Generator_loss:1.3055
# L1_loss:0.1191
# Discriminator_loss:0.7952
#
# EPOCH[125] - STEP[60]
# Generator_loss:2.2803
# L1_loss:0.1266
# Discriminator_loss:0.2503
#
# EPOCH[125] - STEP[70]
# Generator_loss:5.0146
# L1_loss:0.1373
# Discriminator_loss:0.6071
#
# EPOCH[125] - STEP[80]
# Generator_loss:1.7938
# L1_loss:0.1170
# Discriminator_loss:0.7241
#
# EPOCH[125] - STEP[90]
# Generator_loss:5.6424
# L1_loss:0.1179
# Discriminator_loss:0.5540
#
# EPOCH[125] - STEP[100]
# Generator_loss:3.0502
# L1_loss:0.1101
# Discriminator_loss:0.2762
#
# EPOCH[125] - STEP[110]
# Generator_loss:3.4593
# L1_loss:0.1232
# Discriminator_loss:0.1017
#
# EPOCH[125] - STEP[120]
# Generator_loss:2.4049
# L1_loss:0.1358
# Discriminator_loss:0.2704
#
# EPOCH[125] - STEP[130]
# Generator_loss:3.2553
# L1_loss:0.1287
# Discriminator_loss:0.0848
#
# EPOCH[125] - STEP[140]
# Generator_loss:4.8772
# L1_loss:0.1112
# Discriminator_loss:0.0913
#
# EPOCH[125] - STEP[150]
# Generator_loss:2.7427
# L1_loss:0.1027
# Discriminator_loss:1.2175
#
# EPOCH[125] - STEP[160]
# Generator_loss:3.5192
# L1_loss:0.1311
# Discriminator_loss:0.1733
#
# EPOCH[125] - STEP[170]
# Generator_loss:3.6308
# L1_loss:0.1657
# Discriminator_loss:0.0818
#
# EPOCH[125] - STEP[180]
# Generator_loss:4.9916
# L1_loss:0.1230
# Discriminator_loss:0.3819
#
# EPOCH[125] - STEP[190]
# Generator_loss:3.7764
# L1_loss:0.1251
# Discriminator_loss:0.3338
#
# EPOCH[125] - STEP[200]
# Generator_loss:3.2231
# L1_loss:0.1214
# Discriminator_loss:1.0688
#
# EPOCH[125] - STEP[210]
# Generator_loss:1.7644
# L1_loss:0.1566
# Discriminator_loss:0.4906
#
# EPOCH[125] - STEP[220]
# Generator_loss:4.2578
# L1_loss:0.1503
# Discriminator_loss:0.0509
#
# EPOCH[125] - STEP[230]
# Generator_loss:2.6994
# L1_loss:0.1381
# Discriminator_loss:0.1426
#
# EPOCH[125] - STEP[240]
# Generator_loss:3.3351
# L1_loss:0.1450
# Discriminator_loss:0.1942
# EPOCH[125] - STEP[250]
# Generator_loss:3.3454
# L1_loss:0.1273
# Discriminator_loss:0.1514
#
# EPOCH[126] - STEP[10]
# Generator_loss:2.5628
# L1_loss:0.1038
# Discriminator_loss:1.1401
#
# EPOCH[126] - STEP[20]
# Generator_loss:3.1627
# L1_loss:0.1179
# Discriminator_loss:0.2877
#
# EPOCH[126] - STEP[30]
# Generator_loss:3.7794
# L1_loss:0.1110
# Discriminator_loss:0.0652
#
# EPOCH[126] - STEP[40]
# Generator_loss:2.3741
# L1_loss:0.1126
# Discriminator_loss:0.3065
#
# EPOCH[126] - STEP[50]
# Generator_loss:1.5913
# L1_loss:0.1140
# Discriminator_loss:0.7094
#
# EPOCH[126] - STEP[60]
# Generator_loss:3.9246
# L1_loss:0.1760
# Discriminator_loss:0.0535
#
# EPOCH[126] - STEP[70]
# Generator_loss:6.0634
# L1_loss:0.1331
# Discriminator_loss:2.4458
#
# EPOCH[126] - STEP[80]
# Generator_loss:2.6935
# L1_loss:0.1941
# Discriminator_loss:0.1973
#
# EPOCH[126] - STEP[90]
# Generator_loss:6.9302
# L1_loss:0.1523
# Discriminator_loss:0.0216
#
# EPOCH[126] - STEP[100]
# Generator_loss:3.7245
# L1_loss:0.1376
# Discriminator_loss:0.2211
#
# EPOCH[126] - STEP[110]
# Generator_loss:6.4015
# L1_loss:0.1130
# Discriminator_loss:0.0059
#
# EPOCH[126] - STEP[120]
# Generator_loss:4.4345
# L1_loss:0.1143
# Discriminator_loss:0.0611
#
# EPOCH[126] - STEP[130]
# Generator_loss:1.1165
# L1_loss:0.1160
# Discriminator_loss:1.3251
#
# EPOCH[126] - STEP[140]
# Generator_loss:4.8428
# L1_loss:0.1430
# Discriminator_loss:0.0439
#
# EPOCH[126] - STEP[150]
# Generator_loss:4.5958
# L1_loss:0.1211
# Discriminator_loss:0.3108
#
# EPOCH[126] - STEP[160]
# Generator_loss:3.1606
# L1_loss:0.0973
# Discriminator_loss:0.4325
#
# EPOCH[126] - STEP[170]
# Generator_loss:3.7838
# L1_loss:0.1493
# Discriminator_loss:0.0754
#
# EPOCH[126] - STEP[180]
# Generator_loss:1.9805
# L1_loss:0.1169
# Discriminator_loss:0.4649
#
# EPOCH[126] - STEP[190]
# Generator_loss:1.7674
# L1_loss:0.0958
# Discriminator_loss:2.1511
#
# EPOCH[126] - STEP[200]
# Generator_loss:4.5430
# L1_loss:0.1428
# Discriminator_loss:0.1694
#
# EPOCH[126] - STEP[210]
# Generator_loss:3.1438
# L1_loss:0.1167
# Discriminator_loss:0.0995
#
# EPOCH[126] - STEP[220]
# Generator_loss:1.9532
# L1_loss:0.1184
# Discriminator_loss:0.2826
#
# EPOCH[126] - STEP[230]
# Generator_loss:4.7196
# L1_loss:0.1241
# Discriminator_loss:0.3999
#
# EPOCH[126] - STEP[240]
# Generator_loss:2.0267
# L1_loss:0.1416
# Discriminator_loss:0.2704
#
# EPOCH[126] - STEP[250]
# Generator_loss:5.2649
# L1_loss:0.1383
# Discriminator_loss:0.2930
#
# EPOCH[127] - STEP[10]
# Generator_loss:4.3183
# L1_loss:0.1275
# Discriminator_loss:0.1196
#
# EPOCH[127] - STEP[20]
# Generator_loss:5.7153
# L1_loss:0.1398
# Discriminator_loss:0.0185
#
# EPOCH[127] - STEP[30]
# Generator_loss:2.7317
# L1_loss:0.1408
# Discriminator_loss:0.3139
#
# EPOCH[127] - STEP[40]
# Generator_loss:1.2658
# L1_loss:0.1322
# Discriminator_loss:0.8769
#
# EPOCH[127] - STEP[50]
# Generator_loss:4.3415
# L1_loss:0.1647
# Discriminator_loss:0.2094
#
# EPOCH[127] - STEP[60]
# Generator_loss:5.2063
# L1_loss:0.1523
# Discriminator_loss:0.0329
#
# EPOCH[127] - STEP[70]
# Generator_loss:6.3329
# L1_loss:0.1491
# Discriminator_loss:0.0143
#
# EPOCH[127] - STEP[80]
# Generator_loss:3.0038
# L1_loss:0.1061
# Discriminator_loss:3.0915
#
# EPOCH[127] - STEP[90]
# Generator_loss:4.2753
# L1_loss:0.1503
# Discriminator_loss:0.0594
#
# EPOCH[127] - STEP[100]
# Generator_loss:3.3584
# L1_loss:0.1196
# Discriminator_loss:0.1917
#
# EPOCH[127] - STEP[110]
# Generator_loss:4.6752
# L1_loss:0.1632
# Discriminator_loss:0.1254
#
# EPOCH[127] - STEP[120]
# Generator_loss:3.1598
# L1_loss:0.1259
# Discriminator_loss:0.3966
#
# EPOCH[127] - STEP[130]
# Generator_loss:3.3313
# L1_loss:0.1290
# Discriminator_loss:0.0724
#
# EPOCH[127] - STEP[140]
# Generator_loss:5.7476
# L1_loss:0.1172
# Discriminator_loss:0.1549
#
# EPOCH[127] - STEP[150]
# Generator_loss:2.7020
# L1_loss:0.1300
# Discriminator_loss:0.1904
#
# EPOCH[127] - STEP[160]
# Generator_loss:4.1180
# L1_loss:0.1183
# Discriminator_loss:1.0251
#
# EPOCH[127] - STEP[170]
# Generator_loss:4.5919
# L1_loss:0.1142
# Discriminator_loss:0.7517
#
# EPOCH[127] - STEP[180]
# Generator_loss:3.7011
# L1_loss:0.1132
# Discriminator_loss:0.7376
#
# EPOCH[127] - STEP[190]
# Generator_loss:5.4037
# L1_loss:0.1491
# Discriminator_loss:0.0561
#
# EPOCH[127] - STEP[200]
# Generator_loss:3.5649
# L1_loss:0.1178
# Discriminator_loss:0.1704
#
# EPOCH[127] - STEP[210]
# Generator_loss:5.6311
# L1_loss:0.1257
# Discriminator_loss:0.2738
#
# EPOCH[127] - STEP[220]
# Generator_loss:2.9676
# L1_loss:0.1087
# Discriminator_loss:0.2175
#
# EPOCH[127] - STEP[230]
# Generator_loss:2.8499
# L1_loss:0.1316
# Discriminator_loss:0.1646
#
# EPOCH[127] - STEP[240]
# Generator_loss:5.8579
# L1_loss:0.1243
# Discriminator_loss:0.0790
#
# EPOCH[127] - STEP[250]
# Generator_loss:3.5761
# L1_loss:0.1577
# Discriminator_loss:0.0615
#
# EPOCH[128] - STEP[10]
# Generator_loss:3.1624
# L1_loss:0.1537
# Discriminator_loss:0.1126
#
# EPOCH[128] - STEP[20]
# Generator_loss:3.2415
# L1_loss:0.1477
# Discriminator_loss:0.1867
#
# EPOCH[128] - STEP[30]
# Generator_loss:3.1930
# L1_loss:0.1446
# Discriminator_loss:0.2163
#
# EPOCH[128] - STEP[40]
# Generator_loss:5.0596
# L1_loss:0.1246
# Discriminator_loss:0.2010
# EPOCH[128] - STEP[50]
# Generator_loss:3.3194
# L1_loss:0.1168
# Discriminator_loss:0.2307
#
# EPOCH[128] - STEP[60]
# Generator_loss:0.2494
# L1_loss:0.1392
# Discriminator_loss:2.7471
#
# EPOCH[128] - STEP[70]
# Generator_loss:3.8985
# L1_loss:0.1376
# Discriminator_loss:0.1013
#
# EPOCH[128] - STEP[80]
# Generator_loss:3.8367
# L1_loss:0.0898
# Discriminator_loss:1.9663
#
# EPOCH[128] - STEP[90]
# Generator_loss:2.9904
# L1_loss:0.1489
# Discriminator_loss:0.2566
#
# EPOCH[128] - STEP[100]
# Generator_loss:2.9878
# L1_loss:0.1086
# Discriminator_loss:0.2515
#
# EPOCH[128] - STEP[110]
# Generator_loss:5.3165
# L1_loss:0.1201
# Discriminator_loss:0.1614
#
# EPOCH[128] - STEP[120]
# Generator_loss:3.7950
# L1_loss:0.1302
# Discriminator_loss:0.1159
#
# EPOCH[128] - STEP[130]
# Generator_loss:5.4966
# L1_loss:0.1130
# Discriminator_loss:0.0507
#
# EPOCH[128] - STEP[140]
# Generator_loss:6.3913
# L1_loss:0.1074
# Discriminator_loss:0.0196
#
# EPOCH[128] - STEP[150]
# Generator_loss:3.5346
# L1_loss:0.1350
# Discriminator_loss:0.0798
#
# EPOCH[128] - STEP[160]
# Generator_loss:2.4945
# L1_loss:0.1165
# Discriminator_loss:0.1978
#
# EPOCH[128] - STEP[170]
# Generator_loss:3.8090
# L1_loss:0.1427
# Discriminator_loss:0.0638
#
# EPOCH[128] - STEP[180]
# Generator_loss:1.7714
# L1_loss:0.1233
# Discriminator_loss:0.3377
#
# EPOCH[128] - STEP[190]
# Generator_loss:4.5531
# L1_loss:0.1159
# Discriminator_loss:0.2693
#
# EPOCH[128] - STEP[200]
# Generator_loss:4.4246
# L1_loss:0.1430
# Discriminator_loss:0.1279
#
# EPOCH[128] - STEP[210]
# Generator_loss:5.0690
# L1_loss:0.1033
# Discriminator_loss:1.1728
#
# EPOCH[128] - STEP[220]
# Generator_loss:0.4251
# L1_loss:0.1210
# Discriminator_loss:1.5866
#
# EPOCH[128] - STEP[230]
# Generator_loss:5.2377
# L1_loss:0.1431
# Discriminator_loss:0.0231
#
# EPOCH[128] - STEP[240]
# Generator_loss:3.9435
# L1_loss:0.0956
# Discriminator_loss:0.1564
#
# EPOCH[128] - STEP[250]
# Generator_loss:4.1392
# L1_loss:0.1407
# Discriminator_loss:0.0493

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
colored, sketch = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
