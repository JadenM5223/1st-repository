# %% [markdown]
# ## 데이터 불러오기

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
# 이미지 확인
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 이미지 크기 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
# 컬러 이미지와 스케치 이미지로 자르기
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    colored = img[:, :w, :] 
    colored = tf.cast(colored, tf.float32)
    sketch = img[:, w:, :] 
    sketch = tf.cast(sketch, tf.float32)
    return normalize(colored), normalize(sketch)

f = data_path + os.listdir(data_path)[1]
colored, sketch = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(colored))
plt.subplot(1,2,2); plt.imshow(denormalize(sketch))

# %% [markdown]
# ## Augumentation 적용

# %%
# Augumentation 적용

from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %%
# 시각화

plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_colored, augmented_sketch = apply_augmentation(colored, sketch)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow.keras import layers, Input, Model
from tensorflow import data

def get_train(img_path):
    colored, sketch = load_img(img_path)
    colored, sketch = apply_augmentation(colored, sketch)
    return colored, sketch

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
colored, sketch = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(colored[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(sketch[0].astype(np.uint8))

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("✅")
# Out:
# ✅

# %% [markdown]
# ## UNetGenerator 사용하기

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
Discriminator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("✅")
# Out:
# ✅

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %%
EPOCHS = 256

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (colored, sketch) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(colored, sketch)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.9523
# L1_loss:0.3379
# Discriminator_loss:1.3732
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.1895
# L1_loss:0.2746
# Discriminator_loss:1.3187
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.1158
# L1_loss:0.2973
# Discriminator_loss:1.4304
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.4217
# L1_loss:0.2188
# Discriminator_loss:0.6988
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.4789
# L1_loss:0.2814
# Discriminator_loss:0.6151
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.5509
# L1_loss:0.2768
# Discriminator_loss:0.7155
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.4863
# L1_loss:0.2568
# Discriminator_loss:0.6793
#
# EPOCH[1] - STEP[80]
# Generator_loss:2.3373
# L1_loss:0.3004
# Discriminator_loss:0.4191
#
# EPOCH[1] - STEP[90]
# Generator_loss:2.2189
# L1_loss:0.2406
# Discriminator_loss:0.3736
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.4706
# L1_loss:0.2890
# Discriminator_loss:0.5443
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.7221
# L1_loss:0.2501
# Discriminator_loss:0.6296
#
# EPOCH[1] - STEP[120]
# Generator_loss:0.7715
# L1_loss:0.2191
# Discriminator_loss:1.7835
#
# EPOCH[1] - STEP[130]
# Generator_loss:1.4237
# L1_loss:0.2332
# Discriminator_loss:1.0171
#
# EPOCH[1] - STEP[140]
# Generator_loss:2.4841
# L1_loss:0.2346
# Discriminator_loss:0.3026
#
# EPOCH[1] - STEP[150]
# Generator_loss:2.0034
# L1_loss:0.2466
# Discriminator_loss:0.6571
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.0432
# L1_loss:0.2142
# Discriminator_loss:1.1398
#
# EPOCH[1] - STEP[170]
# Generator_loss:2.0433
# L1_loss:0.2397
# Discriminator_loss:0.6197
#
# EPOCH[1] - STEP[180]
# Generator_loss:3.5810
# L1_loss:0.2417
# Discriminator_loss:0.4466
#
# EPOCH[1] - STEP[190]
# Generator_loss:1.5670
# L1_loss:0.2065
# Discriminator_loss:1.1579
#
# EPOCH[1] - STEP[200]
# Generator_loss:2.1805
# L1_loss:0.2281
# Discriminator_loss:0.5355
#
# EPOCH[1] - STEP[210]
# Generator_loss:2.0595
# L1_loss:0.1939
# Discriminator_loss:0.7740
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.3955
# L1_loss:0.2519
# Discriminator_loss:0.5245
#
# EPOCH[1] - STEP[230]
# Generator_loss:1.8225
# L1_loss:0.2107
# Discriminator_loss:0.6726
#
# EPOCH[1] - STEP[240]
# Generator_loss:2.7519
# L1_loss:0.2660
# Discriminator_loss:0.2755
#
# EPOCH[1] - STEP[250]
# Generator_loss:1.3563
# L1_loss:0.2148
# Discriminator_loss:0.7938
#
# EPOCH[2] - STEP[10]
# Generator_loss:1.1869
# L1_loss:0.2783
# Discriminator_loss:0.7536
#
# EPOCH[2] - STEP[20]
# Generator_loss:0.8518
# L1_loss:0.2537
# Discriminator_loss:1.5512
#
# EPOCH[2] - STEP[30]
# Generator_loss:2.3102
# L1_loss:0.2292
# Discriminator_loss:0.9192
#
# EPOCH[2] - STEP[40]
# Generator_loss:2.1980
# L1_loss:0.2274
# Discriminator_loss:0.8163
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.2508
# L1_loss:0.1985
# Discriminator_loss:0.6847
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.7060
# L1_loss:0.2218
# Discriminator_loss:0.7974
#
# EPOCH[2] - STEP[70]
# Generator_loss:0.5390
# L1_loss:0.2321
# Discriminator_loss:1.1466
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.8060
# L1_loss:0.2071
# Discriminator_loss:1.5023
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.4195
# L1_loss:0.2285
# Discriminator_loss:0.8517
#
# EPOCH[2] - STEP[100]
# Generator_loss:2.1757
# L1_loss:0.1941
# Discriminator_loss:0.8648
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.5370
# L1_loss:0.1725
# Discriminator_loss:0.5779
#
# EPOCH[2] - STEP[120]
# Generator_loss:2.0326
# L1_loss:0.1849
# Discriminator_loss:0.4805
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.4195
# L1_loss:0.1922
# Discriminator_loss:1.3684
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.9322
# L1_loss:0.2062
# Discriminator_loss:0.3738
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.4287
# L1_loss:0.1926
# Discriminator_loss:0.9761
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.7081
# L1_loss:0.2004
# Discriminator_loss:0.9884
#
# EPOCH[2] - STEP[170]
# Generator_loss:2.1802
# L1_loss:0.2771
# Discriminator_loss:0.3978
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.1870
# L1_loss:0.2149
# Discriminator_loss:0.6243
#
# EPOCH[2] - STEP[190]
# Generator_loss:1.4314
# L1_loss:0.2003
# Discriminator_loss:1.1441
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.8200
# L1_loss:0.2100
# Discriminator_loss:0.8667
#
# EPOCH[2] - STEP[210]
# Generator_loss:2.7594
# L1_loss:0.2249
# Discriminator_loss:0.3608
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.6238
# L1_loss:0.1963
# Discriminator_loss:0.8809
#
# EPOCH[2] - STEP[230]
# Generator_loss:1.2604
# L1_loss:0.1890
# Discriminator_loss:0.7584
#
# EPOCH[2] - STEP[240]
# Generator_loss:0.5129
# L1_loss:0.1775
# Discriminator_loss:1.2650
#
# EPOCH[2] - STEP[250]
# Generator_loss:2.8642
# L1_loss:0.1622
# Discriminator_loss:2.0759
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.1865
# L1_loss:0.2046
# Discriminator_loss:0.8366
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.0168
# L1_loss:0.1802
# Discriminator_loss:0.8784
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.3180
# L1_loss:0.2189
# Discriminator_loss:0.7884
#
# EPOCH[3] - STEP[40]
# Generator_loss:2.4056
# L1_loss:0.1811
# Discriminator_loss:1.3232
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.7953
# L1_loss:0.1981
# Discriminator_loss:0.5092
#
# EPOCH[3] - STEP[60]
# Generator_loss:0.7788
# L1_loss:0.1741
# Discriminator_loss:1.1353
# EPOCH[3] - STEP[70]
# Generator_loss:0.6021
# L1_loss:0.2213
# Discriminator_loss:1.3900
#
# EPOCH[3] - STEP[80]
# Generator_loss:2.0996
# L1_loss:0.2107
# Discriminator_loss:0.5842
#
# EPOCH[3] - STEP[90]
# Generator_loss:3.6420
# L1_loss:0.1714
# Discriminator_loss:1.1753
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.7112
# L1_loss:0.1891
# Discriminator_loss:0.8783
#
# EPOCH[3] - STEP[110]
# Generator_loss:1.6774
# L1_loss:0.2069
# Discriminator_loss:0.6089
#
# EPOCH[3] - STEP[120]
# Generator_loss:0.6500
# L1_loss:0.2083
# Discriminator_loss:1.4306
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.0709
# L1_loss:0.2304
# Discriminator_loss:0.6208
#
# EPOCH[3] - STEP[140]
# Generator_loss:2.5077
# L1_loss:0.1766
# Discriminator_loss:1.6716
#
# EPOCH[3] - STEP[150]
# Generator_loss:2.3434
# L1_loss:0.1783
# Discriminator_loss:0.5129
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.6424
# L1_loss:0.1618
# Discriminator_loss:0.6988
#
# EPOCH[3] - STEP[170]
# Generator_loss:2.6142
# L1_loss:0.1837
# Discriminator_loss:0.9169
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.0520
# L1_loss:0.2158
# Discriminator_loss:0.6191
#
# EPOCH[3] - STEP[190]
# Generator_loss:2.0668
# L1_loss:0.1929
# Discriminator_loss:1.2023
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.2236
# L1_loss:0.1737
# Discriminator_loss:0.5169
#
# EPOCH[3] - STEP[210]
# Generator_loss:2.8558
# L1_loss:0.1664
# Discriminator_loss:0.5081
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.5286
# L1_loss:0.2174
# Discriminator_loss:0.4262
#
# EPOCH[3] - STEP[230]
# Generator_loss:2.3632
# L1_loss:0.1894
# Discriminator_loss:0.7972
#
# EPOCH[3] - STEP[240]
# Generator_loss:2.4445
# L1_loss:0.1572
# Discriminator_loss:1.3883
#
# EPOCH[3] - STEP[250]
# Generator_loss:1.5461
# L1_loss:0.1736
# Discriminator_loss:0.6570
#
# EPOCH[4] - STEP[10]
# Generator_loss:2.3953
# L1_loss:0.2198
# Discriminator_loss:0.5042
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.5792
# L1_loss:0.1724
# Discriminator_loss:0.7313
#
# EPOCH[4] - STEP[30]
# Generator_loss:1.5972
# L1_loss:0.2681
# Discriminator_loss:0.3985
#
# EPOCH[4] - STEP[40]
# Generator_loss:2.0036
# L1_loss:0.1837
# Discriminator_loss:0.5397
#
# EPOCH[4] - STEP[50]
# Generator_loss:2.0739
# L1_loss:0.1570
# Discriminator_loss:2.3034
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.1226
# L1_loss:0.2260
# Discriminator_loss:0.7164
#
# EPOCH[4] - STEP[70]
# Generator_loss:2.1890
# L1_loss:0.1802
# Discriminator_loss:1.7202
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.5647
# L1_loss:0.1771
# Discriminator_loss:0.5231
#
# EPOCH[4] - STEP[90]
# Generator_loss:1.7071
# L1_loss:0.1882
# Discriminator_loss:0.4274
#
# EPOCH[4] - STEP[100]
# Generator_loss:2.3712
# L1_loss:0.1995
# Discriminator_loss:0.3491
#
# EPOCH[4] - STEP[110]
# Generator_loss:1.4880
# L1_loss:0.2064
# Discriminator_loss:0.4437
#
# EPOCH[4] - STEP[120]
# Generator_loss:1.6310
# L1_loss:0.2113
# Discriminator_loss:0.6080
#
# EPOCH[4] - STEP[130]
# Generator_loss:2.0318
# L1_loss:0.2239
# Discriminator_loss:0.5913
#
# EPOCH[4] - STEP[140]
# Generator_loss:2.0608
# L1_loss:0.2275
# Discriminator_loss:0.3871
#
# EPOCH[4] - STEP[150]
# Generator_loss:1.2111
# L1_loss:0.2046
# Discriminator_loss:0.4909
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.6301
# L1_loss:0.1861
# Discriminator_loss:0.7028
#
# EPOCH[4] - STEP[170]
# Generator_loss:1.6896
# L1_loss:0.1857
# Discriminator_loss:0.4123
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.6621
# L1_loss:0.1940
# Discriminator_loss:0.7551
#
# EPOCH[4] - STEP[190]
# Generator_loss:2.3260
# L1_loss:0.2045
# Discriminator_loss:0.3858
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.2205
# L1_loss:0.1593
# Discriminator_loss:1.8051
#
# EPOCH[4] - STEP[210]
# Generator_loss:1.7463
# L1_loss:0.2037
# Discriminator_loss:0.7193
#
# EPOCH[4] - STEP[220]
# Generator_loss:0.2820
# L1_loss:0.1920
# Discriminator_loss:1.6723
#
# EPOCH[4] - STEP[230]
# Generator_loss:1.0037
# L1_loss:0.1950
# Discriminator_loss:0.8429
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.3234
# L1_loss:0.2334
# Discriminator_loss:0.5408
#
# EPOCH[4] - STEP[250]
# Generator_loss:1.9029
# L1_loss:0.2291
# Discriminator_loss:0.3059
#
# EPOCH[5] - STEP[10]
# Generator_loss:0.9996
# L1_loss:0.1697
# Discriminator_loss:0.6881
#
# EPOCH[5] - STEP[20]
# Generator_loss:0.2810
# L1_loss:0.1709
# Discriminator_loss:2.1524
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.3554
# L1_loss:0.1916
# Discriminator_loss:0.7179
#
# EPOCH[5] - STEP[40]
# Generator_loss:2.1806
# L1_loss:0.1907
# Discriminator_loss:0.8229
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.6577
# L1_loss:0.2004
# Discriminator_loss:0.4833
#
# EPOCH[5] - STEP[60]
# Generator_loss:2.0258
# L1_loss:0.1888
# Discriminator_loss:0.6156
#
# EPOCH[5] - STEP[70]
# Generator_loss:1.1198
# L1_loss:0.1947
# Discriminator_loss:0.7966
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.0491
# L1_loss:0.1698
# Discriminator_loss:0.8427
#
# EPOCH[5] - STEP[90]
# Generator_loss:1.0168
# L1_loss:0.2300
# Discriminator_loss:0.7843
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.0191
# L1_loss:0.1910
# Discriminator_loss:2.1773
#
# EPOCH[5] - STEP[110]
# Generator_loss:0.5278
# L1_loss:0.1945
# Discriminator_loss:1.8795
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.9593
# L1_loss:0.1628
# Discriminator_loss:0.9109
# EPOCH[5] - STEP[130]
# Generator_loss:2.6061
# L1_loss:0.1851
# Discriminator_loss:1.0454
#
# EPOCH[5] - STEP[140]
# Generator_loss:0.9133
# L1_loss:0.1927
# Discriminator_loss:1.0680
#
# EPOCH[5] - STEP[150]
# Generator_loss:1.8028
# L1_loss:0.2316
# Discriminator_loss:0.4060
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.1687
# L1_loss:0.2077
# Discriminator_loss:0.5734
#
# EPOCH[5] - STEP[170]
# Generator_loss:0.3268
# L1_loss:0.2092
# Discriminator_loss:1.8157
#
# EPOCH[5] - STEP[180]
# Generator_loss:2.1842
# L1_loss:0.1783
# Discriminator_loss:0.5035
#
# EPOCH[5] - STEP[190]
# Generator_loss:2.3372
# L1_loss:0.1575
# Discriminator_loss:1.6728
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.4889
# L1_loss:0.1877
# Discriminator_loss:0.4760
#
# EPOCH[5] - STEP[210]
# Generator_loss:0.3535
# L1_loss:0.1913
# Discriminator_loss:1.5082
#
# EPOCH[5] - STEP[220]
# Generator_loss:1.5948
# L1_loss:0.1895
# Discriminator_loss:0.7486
#
# EPOCH[5] - STEP[230]
# Generator_loss:2.2710
# L1_loss:0.1774
# Discriminator_loss:0.4944
#
# EPOCH[5] - STEP[240]
# Generator_loss:2.0406
# L1_loss:0.2437
# Discriminator_loss:0.5138
#
# EPOCH[5] - STEP[250]
# Generator_loss:1.7831
# L1_loss:0.1996
# Discriminator_loss:0.6534
#
# EPOCH[6] - STEP[10]
# Generator_loss:1.0613
# L1_loss:0.2115
# Discriminator_loss:0.6743
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.5767
# L1_loss:0.1712
# Discriminator_loss:0.7354
#
# EPOCH[6] - STEP[30]
# Generator_loss:2.4565
# L1_loss:0.1421
# Discriminator_loss:1.2058
#
# EPOCH[6] - STEP[40]
# Generator_loss:0.7491
# L1_loss:0.1749
# Discriminator_loss:0.9720
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.0978
# L1_loss:0.2074
# Discriminator_loss:0.8207
#
# EPOCH[6] - STEP[60]
# Generator_loss:1.7657
# L1_loss:0.1670
# Discriminator_loss:0.8523
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.6496
# L1_loss:0.1897
# Discriminator_loss:0.7026
#
# EPOCH[6] - STEP[80]
# Generator_loss:2.4825
# L1_loss:0.2314
# Discriminator_loss:0.2759
#
# EPOCH[6] - STEP[90]
# Generator_loss:1.7031
# L1_loss:0.1969
# Discriminator_loss:0.5605
#
# EPOCH[6] - STEP[100]
# Generator_loss:2.1741
# L1_loss:0.2178
# Discriminator_loss:1.5403
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.7515
# L1_loss:0.2057
# Discriminator_loss:0.5286
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.4895
# L1_loss:0.1761
# Discriminator_loss:1.5088
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.8209
# L1_loss:0.1576
# Discriminator_loss:0.5162
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.7294
# L1_loss:0.1825
# Discriminator_loss:0.4703
#
# EPOCH[6] - STEP[150]
# Generator_loss:2.6025
# L1_loss:0.1324
# Discriminator_loss:1.5634
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.2143
# L1_loss:0.1571
# Discriminator_loss:1.1163
#
# EPOCH[6] - STEP[170]
# Generator_loss:2.9781
# L1_loss:0.1688
# Discriminator_loss:0.5676
#
# EPOCH[6] - STEP[180]
# Generator_loss:2.2483
# L1_loss:0.1624
# Discriminator_loss:0.6967
#
# EPOCH[6] - STEP[190]
# Generator_loss:1.6571
# L1_loss:0.1957
# Discriminator_loss:0.5905
#
# EPOCH[6] - STEP[200]
# Generator_loss:2.3862
# L1_loss:0.1996
# Discriminator_loss:0.5116
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.8227
# L1_loss:0.1969
# Discriminator_loss:0.5438
#
# EPOCH[6] - STEP[220]
# Generator_loss:0.5837
# L1_loss:0.2009
# Discriminator_loss:1.1483
#
# EPOCH[6] - STEP[230]
# Generator_loss:3.0492
# L1_loss:0.1909
# Discriminator_loss:1.1847
#
# EPOCH[6] - STEP[240]
# Generator_loss:2.2198
# L1_loss:0.1571
# Discriminator_loss:1.5564
#
# EPOCH[6] - STEP[250]
# Generator_loss:1.3265
# L1_loss:0.1507
# Discriminator_loss:1.1058
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.1714
# L1_loss:0.1741
# Discriminator_loss:0.6994
#
# EPOCH[7] - STEP[20]
# Generator_loss:1.1122
# L1_loss:0.1977
# Discriminator_loss:0.6565
#
# EPOCH[7] - STEP[30]
# Generator_loss:0.7843
# L1_loss:0.1911
# Discriminator_loss:0.7827
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.5857
# L1_loss:0.2447
# Discriminator_loss:0.4536
#
# EPOCH[7] - STEP[50]
# Generator_loss:3.2255
# L1_loss:0.2486
# Discriminator_loss:0.2567
#
# EPOCH[7] - STEP[60]
# Generator_loss:3.4301
# L1_loss:0.2125
# Discriminator_loss:0.5161
#
# EPOCH[7] - STEP[70]
# Generator_loss:2.4082
# L1_loss:0.1661
# Discriminator_loss:1.2249
#
# EPOCH[7] - STEP[80]
# Generator_loss:0.9884
# L1_loss:0.1734
# Discriminator_loss:0.6878
#
# EPOCH[7] - STEP[90]
# Generator_loss:0.6650
# L1_loss:0.1943
# Discriminator_loss:1.3660
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.2441
# L1_loss:0.1736
# Discriminator_loss:0.7011
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.5032
# L1_loss:0.1768
# Discriminator_loss:0.4459
#
# EPOCH[7] - STEP[120]
# Generator_loss:2.1654
# L1_loss:0.1496
# Discriminator_loss:0.5436
#
# EPOCH[7] - STEP[130]
# Generator_loss:2.3373
# L1_loss:0.2185
# Discriminator_loss:0.5458
#
# EPOCH[7] - STEP[140]
# Generator_loss:0.9176
# L1_loss:0.1974
# Discriminator_loss:0.7621
#
# EPOCH[7] - STEP[150]
# Generator_loss:2.3548
# L1_loss:0.1947
# Discriminator_loss:0.2781
#
# EPOCH[7] - STEP[160]
# Generator_loss:0.3235
# L1_loss:0.1935
# Discriminator_loss:2.0257
#
# EPOCH[7] - STEP[170]
# Generator_loss:0.6087
# L1_loss:0.2111
# Discriminator_loss:1.1822
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.2653
# L1_loss:0.2115
# Discriminator_loss:0.5124
# EPOCH[7] - STEP[190]
# Generator_loss:1.7212
# L1_loss:0.2209
# Discriminator_loss:0.5616
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.9925
# L1_loss:0.2307
# Discriminator_loss:0.4103
#
# EPOCH[7] - STEP[210]
# Generator_loss:1.2931
# L1_loss:0.1804
# Discriminator_loss:1.0023
#
# EPOCH[7] - STEP[220]
# Generator_loss:2.9432
# L1_loss:0.1542
# Discriminator_loss:1.3844
#
# EPOCH[7] - STEP[230]
# Generator_loss:1.9337
# L1_loss:0.1821
# Discriminator_loss:1.1717
#
# EPOCH[7] - STEP[240]
# Generator_loss:2.6534
# L1_loss:0.2200
# Discriminator_loss:0.4752
#
# EPOCH[7] - STEP[250]
# Generator_loss:2.1213
# L1_loss:0.1559
# Discriminator_loss:1.4478
#
# EPOCH[8] - STEP[10]
# Generator_loss:2.4425
# L1_loss:0.1528
# Discriminator_loss:1.5006
#
# EPOCH[8] - STEP[20]
# Generator_loss:2.2813
# L1_loss:0.1516
# Discriminator_loss:1.2539
#
# EPOCH[8] - STEP[30]
# Generator_loss:2.2806
# L1_loss:0.1901
# Discriminator_loss:0.6247
#
# EPOCH[8] - STEP[40]
# Generator_loss:1.7884
# L1_loss:0.1759
# Discriminator_loss:0.9195
#
# EPOCH[8] - STEP[50]
# Generator_loss:2.9272
# L1_loss:0.1657
# Discriminator_loss:0.4722
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.1926
# L1_loss:0.1652
# Discriminator_loss:1.0739
#
# EPOCH[8] - STEP[70]
# Generator_loss:1.1100
# L1_loss:0.1775
# Discriminator_loss:0.5236
#
# EPOCH[8] - STEP[80]
# Generator_loss:1.5152
# L1_loss:0.1893
# Discriminator_loss:0.7852
#
# EPOCH[8] - STEP[90]
# Generator_loss:2.2919
# L1_loss:0.1480
# Discriminator_loss:0.5684
#
# EPOCH[8] - STEP[100]
# Generator_loss:1.5374
# L1_loss:0.2227
# Discriminator_loss:0.4758
#
# EPOCH[8] - STEP[110]
# Generator_loss:2.7319
# L1_loss:0.1893
# Discriminator_loss:0.7377
#
# EPOCH[8] - STEP[120]
# Generator_loss:0.9334
# L1_loss:0.1636
# Discriminator_loss:0.9451
#
# EPOCH[8] - STEP[130]
# Generator_loss:1.2637
# L1_loss:0.1939
# Discriminator_loss:0.7147
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.7660
# L1_loss:0.1902
# Discriminator_loss:1.4285
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.7936
# L1_loss:0.1990
# Discriminator_loss:0.4214
#
# EPOCH[8] - STEP[160]
# Generator_loss:0.7692
# L1_loss:0.2017
# Discriminator_loss:1.2206
#
# EPOCH[8] - STEP[170]
# Generator_loss:2.8442
# L1_loss:0.1899
# Discriminator_loss:0.8873
#
# EPOCH[8] - STEP[180]
# Generator_loss:1.1925
# L1_loss:0.1960
# Discriminator_loss:0.9232
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.3369
# L1_loss:0.1753
# Discriminator_loss:0.5771
#
# EPOCH[8] - STEP[200]
# Generator_loss:2.4104
# L1_loss:0.1442
# Discriminator_loss:0.2333
#
# EPOCH[8] - STEP[210]
# Generator_loss:1.1173
# L1_loss:0.2076
# Discriminator_loss:0.4903
#
# EPOCH[8] - STEP[220]
# Generator_loss:2.7790
# L1_loss:0.1957
# Discriminator_loss:1.0281
#
# EPOCH[8] - STEP[230]
# Generator_loss:1.2663
# L1_loss:0.1517
# Discriminator_loss:0.6375
#
# EPOCH[8] - STEP[240]
# Generator_loss:2.5500
# L1_loss:0.1648
# Discriminator_loss:1.0251
#
# EPOCH[8] - STEP[250]
# Generator_loss:2.1409
# L1_loss:0.1989
# Discriminator_loss:0.6007
#
# EPOCH[9] - STEP[10]
# Generator_loss:2.1445
# L1_loss:0.1761
# Discriminator_loss:0.8768
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.8626
# L1_loss:0.1689
# Discriminator_loss:0.4798
#
# EPOCH[9] - STEP[30]
# Generator_loss:1.5275
# L1_loss:0.1559
# Discriminator_loss:0.6620
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.6051
# L1_loss:0.1931
# Discriminator_loss:0.7550
#
# EPOCH[9] - STEP[50]
# Generator_loss:2.7913
# L1_loss:0.1418
# Discriminator_loss:0.4969
#
# EPOCH[9] - STEP[60]
# Generator_loss:2.2195
# L1_loss:0.1838
# Discriminator_loss:0.4897
#
# EPOCH[9] - STEP[70]
# Generator_loss:1.6434
# L1_loss:0.2267
# Discriminator_loss:0.5950
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.4056
# L1_loss:0.1805
# Discriminator_loss:0.9207
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.8313
# L1_loss:0.2272
# Discriminator_loss:0.4445
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.7546
# L1_loss:0.1910
# Discriminator_loss:1.2956
#
# EPOCH[9] - STEP[110]
# Generator_loss:1.2260
# L1_loss:0.1771
# Discriminator_loss:0.5060
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.3756
# L1_loss:0.1965
# Discriminator_loss:0.4720
#
# EPOCH[9] - STEP[130]
# Generator_loss:2.2286
# L1_loss:0.2037
# Discriminator_loss:0.4271
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.6829
# L1_loss:0.1625
# Discriminator_loss:1.6779
#
# EPOCH[9] - STEP[150]
# Generator_loss:1.2186
# L1_loss:0.2107
# Discriminator_loss:0.6413
#
# EPOCH[9] - STEP[160]
# Generator_loss:0.7377
# L1_loss:0.2090
# Discriminator_loss:1.1707
#
# EPOCH[9] - STEP[170]
# Generator_loss:1.1052
# L1_loss:0.2035
# Discriminator_loss:0.6569
#
# EPOCH[9] - STEP[180]
# Generator_loss:0.8589
# L1_loss:0.1993
# Discriminator_loss:0.7630
#
# EPOCH[9] - STEP[190]
# Generator_loss:1.4563
# L1_loss:0.1865
# Discriminator_loss:0.3850
#
# EPOCH[9] - STEP[200]
# Generator_loss:0.9986
# L1_loss:0.1508
# Discriminator_loss:0.8605
#
# EPOCH[9] - STEP[210]
# Generator_loss:2.2711
# L1_loss:0.1638
# Discriminator_loss:0.3703
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.6173
# L1_loss:0.1708
# Discriminator_loss:0.5954
#
# EPOCH[9] - STEP[230]
# Generator_loss:1.8384
# L1_loss:0.1951
# Discriminator_loss:0.3980
#
# EPOCH[9] - STEP[240]
# Generator_loss:1.8060
# L1_loss:0.1911
# Discriminator_loss:0.5936
# EPOCH[9] - STEP[250]
# Generator_loss:2.2375
# L1_loss:0.2177
# Discriminator_loss:0.6289
#
# EPOCH[10] - STEP[10]
# Generator_loss:2.8517
# L1_loss:0.1918
# Discriminator_loss:0.5597
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.1993
# L1_loss:0.1431
# Discriminator_loss:1.0118
#
# EPOCH[10] - STEP[30]
# Generator_loss:1.1656
# L1_loss:0.1630
# Discriminator_loss:0.4861
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.5543
# L1_loss:0.1784
# Discriminator_loss:0.4185
#
# EPOCH[10] - STEP[50]
# Generator_loss:1.3769
# L1_loss:0.1656
# Discriminator_loss:0.5572
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.9149
# L1_loss:0.1862
# Discriminator_loss:0.4839
#
# EPOCH[10] - STEP[70]
# Generator_loss:2.3083
# L1_loss:0.2125
# Discriminator_loss:0.2091
#
# EPOCH[10] - STEP[80]
# Generator_loss:3.0909
# L1_loss:0.1434
# Discriminator_loss:1.3981
#
# EPOCH[10] - STEP[90]
# Generator_loss:2.0748
# L1_loss:0.1811
# Discriminator_loss:1.2508
#
# EPOCH[10] - STEP[100]
# Generator_loss:1.5850
# L1_loss:0.1778
# Discriminator_loss:0.8357
#
# EPOCH[10] - STEP[110]
# Generator_loss:3.0987
# L1_loss:0.1976
# Discriminator_loss:0.1833
#
# EPOCH[10] - STEP[120]
# Generator_loss:2.1622
# L1_loss:0.1675
# Discriminator_loss:0.7166
#
# EPOCH[10] - STEP[130]
# Generator_loss:2.5382
# L1_loss:0.1809
# Discriminator_loss:0.7628
#
# EPOCH[10] - STEP[140]
# Generator_loss:2.8001
# L1_loss:0.1745
# Discriminator_loss:0.3116
#
# EPOCH[10] - STEP[150]
# Generator_loss:2.5002
# L1_loss:0.1589
# Discriminator_loss:1.7481
#
# EPOCH[10] - STEP[160]
# Generator_loss:0.7661
# L1_loss:0.1708
# Discriminator_loss:0.9312
#
# EPOCH[10] - STEP[170]
# Generator_loss:1.6031
# L1_loss:0.2325
# Discriminator_loss:0.7783
#
# EPOCH[10] - STEP[180]
# Generator_loss:0.9639
# L1_loss:0.1846
# Discriminator_loss:0.6249
#
# EPOCH[10] - STEP[190]
# Generator_loss:2.4063
# L1_loss:0.1672
# Discriminator_loss:0.8568
#
# EPOCH[10] - STEP[200]
# Generator_loss:2.5241
# L1_loss:0.1890
# Discriminator_loss:0.7982
#
# EPOCH[10] - STEP[210]
# Generator_loss:1.4437
# L1_loss:0.1904
# Discriminator_loss:0.8396
#
# EPOCH[10] - STEP[220]
# Generator_loss:0.9881
# L1_loss:0.1701
# Discriminator_loss:0.6662
#
# EPOCH[10] - STEP[230]
# Generator_loss:1.9491
# L1_loss:0.1823
# Discriminator_loss:0.4481
#
# EPOCH[10] - STEP[240]
# Generator_loss:2.3649
# L1_loss:0.1804
# Discriminator_loss:0.5994
#
# EPOCH[10] - STEP[250]
# Generator_loss:2.0562
# L1_loss:0.1684
# Discriminator_loss:0.9294
#
# EPOCH[11] - STEP[10]
# Generator_loss:2.0252
# L1_loss:0.1540
# Discriminator_loss:0.3674
#
# EPOCH[11] - STEP[20]
# Generator_loss:1.6194
# L1_loss:0.1659
# Discriminator_loss:0.6368
#
# EPOCH[11] - STEP[30]
# Generator_loss:3.2562
# L1_loss:0.1728
# Discriminator_loss:1.6375
#
# EPOCH[11] - STEP[40]
# Generator_loss:1.1698
# L1_loss:0.1713
# Discriminator_loss:0.8705
#
# EPOCH[11] - STEP[50]
# Generator_loss:1.9723
# L1_loss:0.1785
# Discriminator_loss:0.4738
#
# EPOCH[11] - STEP[60]
# Generator_loss:1.4252
# L1_loss:0.1483
# Discriminator_loss:1.0106
#
# EPOCH[11] - STEP[70]
# Generator_loss:1.9791
# L1_loss:0.1570
# Discriminator_loss:0.3470
#
# EPOCH[11] - STEP[80]
# Generator_loss:3.1718
# L1_loss:0.1656
# Discriminator_loss:1.4461
#
# EPOCH[11] - STEP[90]
# Generator_loss:2.4206
# L1_loss:0.1592
# Discriminator_loss:0.8380
#
# EPOCH[11] - STEP[100]
# Generator_loss:1.6877
# L1_loss:0.2108
# Discriminator_loss:0.3958
#
# EPOCH[11] - STEP[110]
# Generator_loss:1.7324
# L1_loss:0.1731
# Discriminator_loss:0.4119
#
# EPOCH[11] - STEP[120]
# Generator_loss:3.0017
# L1_loss:0.1813
# Discriminator_loss:0.7405
#
# EPOCH[11] - STEP[130]
# Generator_loss:1.5087
# L1_loss:0.1605
# Discriminator_loss:1.3787
#
# EPOCH[11] - STEP[140]
# Generator_loss:1.1495
# L1_loss:0.1700
# Discriminator_loss:1.2536
#
# EPOCH[11] - STEP[150]
# Generator_loss:1.5670
# L1_loss:0.1772
# Discriminator_loss:0.7286
#
# EPOCH[11] - STEP[160]
# Generator_loss:0.4873
# L1_loss:0.2032
# Discriminator_loss:1.1669
#
# EPOCH[11] - STEP[170]
# Generator_loss:2.9595
# L1_loss:0.1793
# Discriminator_loss:0.9373
#
# EPOCH[11] - STEP[180]
# Generator_loss:0.9295
# L1_loss:0.2132
# Discriminator_loss:0.7013
#
# EPOCH[11] - STEP[190]
# Generator_loss:0.9530
# L1_loss:0.1453
# Discriminator_loss:0.9380
#
# EPOCH[11] - STEP[200]
# Generator_loss:0.6581
# L1_loss:0.1764
# Discriminator_loss:1.3832
#
# EPOCH[11] - STEP[210]
# Generator_loss:1.0895
# L1_loss:0.1772
# Discriminator_loss:0.6239
#
# EPOCH[11] - STEP[220]
# Generator_loss:2.6955
# L1_loss:0.1719
# Discriminator_loss:1.1438
#
# EPOCH[11] - STEP[230]
# Generator_loss:1.0988
# L1_loss:0.1762
# Discriminator_loss:0.7173
#
# EPOCH[11] - STEP[240]
# Generator_loss:2.4209
# L1_loss:0.1882
# Discriminator_loss:0.4933
#
# EPOCH[11] - STEP[250]
# Generator_loss:1.6129
# L1_loss:0.2039
# Discriminator_loss:0.6342
#
# EPOCH[12] - STEP[10]
# Generator_loss:2.3375
# L1_loss:0.1825
# Discriminator_loss:0.3667
#
# EPOCH[12] - STEP[20]
# Generator_loss:0.7819
# L1_loss:0.1693
# Discriminator_loss:0.9760
#
# EPOCH[12] - STEP[30]
# Generator_loss:2.2987
# L1_loss:0.1706
# Discriminator_loss:1.2314
#
# EPOCH[12] - STEP[40]
# Generator_loss:2.6954
# L1_loss:0.1603
# Discriminator_loss:0.4808
#
# EPOCH[12] - STEP[50]
# Generator_loss:2.7986
# L1_loss:0.1384
# Discriminator_loss:1.3828
# EPOCH[12] - STEP[60]
# Generator_loss:2.9265
# L1_loss:0.1907
# Discriminator_loss:0.6799
#
# EPOCH[12] - STEP[70]
# Generator_loss:1.9744
# L1_loss:0.2299
# Discriminator_loss:0.2760
#
# EPOCH[12] - STEP[80]
# Generator_loss:2.1643
# L1_loss:0.1706
# Discriminator_loss:0.8633
#
# EPOCH[12] - STEP[90]
# Generator_loss:1.0589
# L1_loss:0.1866
# Discriminator_loss:0.7031
#
# EPOCH[12] - STEP[100]
# Generator_loss:2.2447
# L1_loss:0.2094
# Discriminator_loss:0.1741
#
# EPOCH[12] - STEP[110]
# Generator_loss:0.3103
# L1_loss:0.1871
# Discriminator_loss:1.5972
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.7301
# L1_loss:0.1460
# Discriminator_loss:1.4229
#
# EPOCH[12] - STEP[130]
# Generator_loss:1.8427
# L1_loss:0.1820
# Discriminator_loss:0.5426
#
# EPOCH[12] - STEP[140]
# Generator_loss:1.1674
# L1_loss:0.1794
# Discriminator_loss:0.7891
#
# EPOCH[12] - STEP[150]
# Generator_loss:3.2624
# L1_loss:0.1434
# Discriminator_loss:0.9142
#
# EPOCH[12] - STEP[160]
# Generator_loss:3.1062
# L1_loss:0.1742
# Discriminator_loss:0.5442
#
# EPOCH[12] - STEP[170]
# Generator_loss:1.9433
# L1_loss:0.1867
# Discriminator_loss:0.8042
#
# EPOCH[12] - STEP[180]
# Generator_loss:1.8272
# L1_loss:0.1535
# Discriminator_loss:0.4483
#
# EPOCH[12] - STEP[190]
# Generator_loss:1.3824
# L1_loss:0.1468
# Discriminator_loss:0.5338
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.3693
# L1_loss:0.1574
# Discriminator_loss:0.8472
#
# EPOCH[12] - STEP[210]
# Generator_loss:1.2960
# L1_loss:0.1897
# Discriminator_loss:0.4905
#
# EPOCH[12] - STEP[220]
# Generator_loss:1.2129
# L1_loss:0.2151
# Discriminator_loss:0.5326
#
# EPOCH[12] - STEP[230]
# Generator_loss:0.6962
# L1_loss:0.1957
# Discriminator_loss:1.1741
#
# EPOCH[12] - STEP[240]
# Generator_loss:1.7332
# L1_loss:0.1647
# Discriminator_loss:1.2861
#
# EPOCH[12] - STEP[250]
# Generator_loss:1.4766
# L1_loss:0.1656
# Discriminator_loss:1.4860
#
# EPOCH[13] - STEP[10]
# Generator_loss:2.5965
# L1_loss:0.1732
# Discriminator_loss:1.4451
#
# EPOCH[13] - STEP[20]
# Generator_loss:2.5655
# L1_loss:0.1722
# Discriminator_loss:0.6028
#
# EPOCH[13] - STEP[30]
# Generator_loss:2.0133
# L1_loss:0.1782
# Discriminator_loss:1.0231
#
# EPOCH[13] - STEP[40]
# Generator_loss:0.8314
# L1_loss:0.1992
# Discriminator_loss:0.7394
#
# EPOCH[13] - STEP[50]
# Generator_loss:1.5441
# L1_loss:0.1843
# Discriminator_loss:0.5071
#
# EPOCH[13] - STEP[60]
# Generator_loss:2.2717
# L1_loss:0.1688
# Discriminator_loss:0.5405
#
# EPOCH[13] - STEP[70]
# Generator_loss:1.5591
# L1_loss:0.1646
# Discriminator_loss:0.4117
#
# EPOCH[13] - STEP[80]
# Generator_loss:2.1012
# L1_loss:0.1616
# Discriminator_loss:0.7735
#
# EPOCH[13] - STEP[90]
# Generator_loss:1.2858
# L1_loss:0.1962
# Discriminator_loss:0.6706
#
# EPOCH[13] - STEP[100]
# Generator_loss:0.8048
# L1_loss:0.1738
# Discriminator_loss:1.0289
#
# EPOCH[13] - STEP[110]
# Generator_loss:1.7305
# L1_loss:0.1458
# Discriminator_loss:1.8080
#
# EPOCH[13] - STEP[120]
# Generator_loss:1.8519
# L1_loss:0.1766
# Discriminator_loss:0.5465
#
# EPOCH[13] - STEP[130]
# Generator_loss:0.4608
# L1_loss:0.1481
# Discriminator_loss:1.2413
#
# EPOCH[13] - STEP[140]
# Generator_loss:2.1216
# L1_loss:0.1565
# Discriminator_loss:0.6272
#
# EPOCH[13] - STEP[150]
# Generator_loss:2.9851
# L1_loss:0.1493
# Discriminator_loss:0.4739
#
# EPOCH[13] - STEP[160]
# Generator_loss:1.3617
# L1_loss:0.1766
# Discriminator_loss:0.8366
#
# EPOCH[13] - STEP[170]
# Generator_loss:1.9202
# L1_loss:0.1710
# Discriminator_loss:0.4549
#
# EPOCH[13] - STEP[180]
# Generator_loss:1.3845
# L1_loss:0.1686
# Discriminator_loss:0.9910
#
# EPOCH[13] - STEP[190]
# Generator_loss:1.0247
# L1_loss:0.1832
# Discriminator_loss:0.7829
#
# EPOCH[13] - STEP[200]
# Generator_loss:2.6212
# L1_loss:0.1461
# Discriminator_loss:1.4381
#
# EPOCH[13] - STEP[210]
# Generator_loss:1.5564
# L1_loss:0.1637
# Discriminator_loss:0.3609
#
# EPOCH[13] - STEP[220]
# Generator_loss:1.8733
# L1_loss:0.1725
# Discriminator_loss:0.4102
#
# EPOCH[13] - STEP[230]
# Generator_loss:1.7323
# L1_loss:0.1808
# Discriminator_loss:0.5034
#
# EPOCH[13] - STEP[240]
# Generator_loss:1.2279
# L1_loss:0.1755
# Discriminator_loss:0.4796
#
# EPOCH[13] - STEP[250]
# ...
# Generator_loss:3.8814
# L1_loss:0.1015
# Discriminator_loss:0.0477
#
# EPOCH[252] - STEP[200]
# Generator_loss:7.1738
# L1_loss:0.0903
# Discriminator_loss:0.0632
#
# EPOCH[252] - STEP[210]
# Generator_loss:8.4730
# L1_loss:0.1236
# Discriminator_loss:0.0075
#
# EPOCH[252] - STEP[220]
# Generator_loss:6.4856
# L1_loss:0.1250
# Discriminator_loss:0.1265
#
# EPOCH[252] - STEP[230]
# Generator_loss:2.6972
# L1_loss:0.1117
# Discriminator_loss:0.3566
#
# EPOCH[252] - STEP[240]
# Generator_loss:4.4201
# L1_loss:0.1301
# Discriminator_loss:0.0301
#
# EPOCH[252] - STEP[250]
# Generator_loss:3.6360
# L1_loss:0.1319
# Discriminator_loss:0.0888
#
# EPOCH[253] - STEP[10]
# Generator_loss:3.6218
# L1_loss:0.1272
# Discriminator_loss:0.1828
#
# EPOCH[253] - STEP[20]
# Generator_loss:5.7230
# L1_loss:0.1010
# Discriminator_loss:1.5568
#
# EPOCH[253] - STEP[30]
# Generator_loss:3.3207
# L1_loss:0.1219
# Discriminator_loss:0.1570
#
# EPOCH[253] - STEP[40]
# Generator_loss:0.8315
# L1_loss:0.1102
# Discriminator_loss:1.0940
#
# EPOCH[253] - STEP[50]
# Generator_loss:10.6902
# L1_loss:0.1287
# Discriminator_loss:0.0500
#
# EPOCH[253] - STEP[60]
# Generator_loss:4.0185
# L1_loss:0.1070
# Discriminator_loss:0.0673
#
# EPOCH[253] - STEP[70]
# Generator_loss:3.4716
# L1_loss:0.0965
# Discriminator_loss:0.2259
#
# EPOCH[253] - STEP[80]
# Generator_loss:5.8287
# L1_loss:0.1246
# Discriminator_loss:0.0104
#
# EPOCH[253] - STEP[90]
# Generator_loss:3.2753
# L1_loss:0.1097
# Discriminator_loss:0.1509
#
# EPOCH[253] - STEP[100]
# Generator_loss:8.3805
# L1_loss:0.1025
# Discriminator_loss:0.0107
#
# EPOCH[253] - STEP[110]
# Generator_loss:2.3797
# L1_loss:0.1346
# Discriminator_loss:0.2169
#
# EPOCH[253] - STEP[120]
# Generator_loss:2.2467
# L1_loss:0.1086
# Discriminator_loss:0.2745
#
# EPOCH[253] - STEP[130]
# Generator_loss:6.2474
# L1_loss:0.1425
# Discriminator_loss:0.0080
#
# EPOCH[253] - STEP[140]
# Generator_loss:6.3918
# L1_loss:0.1192
# Discriminator_loss:0.0293
# EPOCH[253] - STEP[150]
# Generator_loss:4.1324
# L1_loss:0.1241
# Discriminator_loss:0.1000
#
# EPOCH[253] - STEP[160]
# Generator_loss:3.5740
# L1_loss:0.1264
# Discriminator_loss:0.1963
#
# EPOCH[253] - STEP[170]
# Generator_loss:2.2898
# L1_loss:0.1226
# Discriminator_loss:0.3625
#
# EPOCH[253] - STEP[180]
# Generator_loss:2.9305
# L1_loss:0.1334
# Discriminator_loss:0.2511
#
# EPOCH[253] - STEP[190]
# Generator_loss:4.1738
# L1_loss:0.1412
# Discriminator_loss:0.5180
#
# EPOCH[253] - STEP[200]
# Generator_loss:6.7850
# L1_loss:0.1331
# Discriminator_loss:0.0966
#
# EPOCH[253] - STEP[210]
# Generator_loss:2.0767
# L1_loss:0.1139
# Discriminator_loss:0.2299
#
# EPOCH[253] - STEP[220]
# Generator_loss:6.6755
# L1_loss:0.0991
# Discriminator_loss:0.1684
#
# EPOCH[253] - STEP[230]
# Generator_loss:7.2175
# L1_loss:0.1200
# Discriminator_loss:0.0386
#
# EPOCH[253] - STEP[240]
# Generator_loss:2.7487
# L1_loss:0.0949
# Discriminator_loss:0.1327
#
# EPOCH[253] - STEP[250]
# Generator_loss:5.2013
# L1_loss:0.1172
# Discriminator_loss:0.1124
#
# EPOCH[254] - STEP[10]
# Generator_loss:4.9427
# L1_loss:0.1066
# Discriminator_loss:0.0477
#
# EPOCH[254] - STEP[20]
# Generator_loss:6.6631
# L1_loss:0.1250
# Discriminator_loss:0.0068
#
# EPOCH[254] - STEP[30]
# Generator_loss:5.3476
# L1_loss:0.1159
# Discriminator_loss:0.0404
#
# EPOCH[254] - STEP[40]
# Generator_loss:4.5810
# L1_loss:0.1286
# Discriminator_loss:0.0928
#
# EPOCH[254] - STEP[50]
# Generator_loss:5.7763
# L1_loss:0.0951
# Discriminator_loss:0.0927
#
# EPOCH[254] - STEP[60]
# Generator_loss:10.2421
# L1_loss:0.1186
# Discriminator_loss:0.1529
#
# EPOCH[254] - STEP[70]
# Generator_loss:9.0535
# L1_loss:0.1163
# Discriminator_loss:0.0388
#
# EPOCH[254] - STEP[80]
# Generator_loss:5.8512
# L1_loss:0.1089
# Discriminator_loss:0.0174
#
# EPOCH[254] - STEP[90]
# Generator_loss:2.4428
# L1_loss:0.1162
# Discriminator_loss:0.2340
#
# EPOCH[254] - STEP[100]
# Generator_loss:6.8100
# L1_loss:0.1107
# Discriminator_loss:0.0369
#
# EPOCH[254] - STEP[110]
# Generator_loss:1.4064
# L1_loss:0.1070
# Discriminator_loss:0.9080
#
# EPOCH[254] - STEP[120]
# Generator_loss:1.0196
# L1_loss:0.1120
# Discriminator_loss:1.1832
#
# EPOCH[254] - STEP[130]
# Generator_loss:8.9560
# L1_loss:0.0967
# Discriminator_loss:0.1239
#
# EPOCH[254] - STEP[140]
# Generator_loss:5.3005
# L1_loss:0.1192
# Discriminator_loss:0.0460
#
# EPOCH[254] - STEP[150]
# Generator_loss:5.2655
# L1_loss:0.1186
# Discriminator_loss:0.0759
#
# EPOCH[254] - STEP[160]
# Generator_loss:6.2773
# L1_loss:0.1177
# Discriminator_loss:0.0241
#
# EPOCH[254] - STEP[170]
# Generator_loss:2.8023
# L1_loss:0.1219
# Discriminator_loss:0.2242
#
# EPOCH[254] - STEP[180]
# Generator_loss:3.6314
# L1_loss:0.1203
# Discriminator_loss:0.2363
#
# EPOCH[254] - STEP[190]
# Generator_loss:2.4740
# L1_loss:0.1197
# Discriminator_loss:0.1665
#
# EPOCH[254] - STEP[200]
# Generator_loss:6.1798
# L1_loss:0.1270
# Discriminator_loss:0.0190
#
# EPOCH[254] - STEP[210]
# Generator_loss:2.5803
# L1_loss:0.1513
# Discriminator_loss:0.1803
#
# EPOCH[254] - STEP[220]
# Generator_loss:5.8251
# L1_loss:0.0929
# Discriminator_loss:0.0159
#
# EPOCH[254] - STEP[230]
# Generator_loss:6.8788
# L1_loss:0.1058
# Discriminator_loss:0.0223
#
# EPOCH[254] - STEP[240]
# Generator_loss:2.3364
# L1_loss:0.0854
# Discriminator_loss:0.2601
#
# EPOCH[254] - STEP[250]
# Generator_loss:0.7929
# L1_loss:0.1230
# Discriminator_loss:1.3476
#
# EPOCH[255] - STEP[10]
# Generator_loss:3.5098
# L1_loss:0.0914
# Discriminator_loss:0.2835
#
# EPOCH[255] - STEP[20]
# Generator_loss:8.2530
# L1_loss:0.1150
# Discriminator_loss:0.0480
#
# EPOCH[255] - STEP[30]
# Generator_loss:2.3335
# L1_loss:0.0955
# Discriminator_loss:0.6423
#
# EPOCH[255] - STEP[40]
# Generator_loss:3.9475
# L1_loss:0.1261
# Discriminator_loss:0.0956
#
# EPOCH[255] - STEP[50]
# Generator_loss:5.6999
# L1_loss:0.1126
# Discriminator_loss:2.9110
#
# EPOCH[255] - STEP[60]
# Generator_loss:4.9233
# L1_loss:0.1113
# Discriminator_loss:0.1916
#
# EPOCH[255] - STEP[70]
# Generator_loss:4.5729
# L1_loss:0.1060
# Discriminator_loss:0.0751
#
# EPOCH[255] - STEP[80]
# Generator_loss:5.6879
# L1_loss:0.1293
# Discriminator_loss:0.0609
#
# EPOCH[255] - STEP[90]
# Generator_loss:2.5111
# L1_loss:0.1599
# Discriminator_loss:0.2374
#
# EPOCH[255] - STEP[100]
# Generator_loss:6.1973
# L1_loss:0.1138
# Discriminator_loss:0.0136
#
# EPOCH[255] - STEP[110]
# Generator_loss:7.1806
# L1_loss:0.1385
# Discriminator_loss:0.0061
#
# EPOCH[255] - STEP[120]
# Generator_loss:7.3309
# L1_loss:0.1142
# Discriminator_loss:0.0220
#
# EPOCH[255] - STEP[130]
# Generator_loss:7.4841
# L1_loss:0.1381
# Discriminator_loss:0.0020
#
# EPOCH[255] - STEP[140]
# Generator_loss:3.7744
# L1_loss:0.1005
# Discriminator_loss:0.6165
#
# EPOCH[255] - STEP[150]
# Generator_loss:3.0829
# L1_loss:0.1072
# Discriminator_loss:0.5841
#
# EPOCH[255] - STEP[160]
# Generator_loss:5.3558
# L1_loss:0.1168
# Discriminator_loss:0.2279
#
# EPOCH[255] - STEP[170]
# Generator_loss:2.9421
# L1_loss:0.1590
# Discriminator_loss:0.1232
#
# EPOCH[255] - STEP[180]
# Generator_loss:4.4955
# L1_loss:0.1141
# Discriminator_loss:0.0465
#
# EPOCH[255] - STEP[190]
# Generator_loss:6.3099
# L1_loss:0.1127
# Discriminator_loss:0.0067
# EPOCH[255] - STEP[200]
# Generator_loss:1.4939
# L1_loss:0.1155
# Discriminator_loss:0.4358
#
# EPOCH[255] - STEP[210]
# Generator_loss:6.7428
# L1_loss:0.0937
# Discriminator_loss:0.0097
#
# EPOCH[255] - STEP[220]
# Generator_loss:9.4931
# L1_loss:0.1616
# Discriminator_loss:0.0627
#
# EPOCH[255] - STEP[230]
# Generator_loss:3.3566
# L1_loss:0.1438
# Discriminator_loss:0.0873
#
# EPOCH[255] - STEP[240]
# Generator_loss:8.9020
# L1_loss:0.1109
# Discriminator_loss:0.4320
#
# EPOCH[255] - STEP[250]
# Generator_loss:2.1228
# L1_loss:0.1150
# Discriminator_loss:0.2572
#
# EPOCH[256] - STEP[10]
# Generator_loss:4.2383
# L1_loss:0.0892
# Discriminator_loss:0.0985
#
# EPOCH[256] - STEP[20]
# Generator_loss:3.9668
# L1_loss:0.1311
# Discriminator_loss:0.0600
#
# EPOCH[256] - STEP[30]
# Generator_loss:3.8975
# L1_loss:0.1058
# Discriminator_loss:0.1145
#
# EPOCH[256] - STEP[40]
# Generator_loss:3.5789
# L1_loss:0.1460
# Discriminator_loss:0.1113
#
# EPOCH[256] - STEP[50]
# Generator_loss:5.9323
# L1_loss:0.1185
# Discriminator_loss:0.0291
#
# EPOCH[256] - STEP[60]
# Generator_loss:2.2192
# L1_loss:0.0993
# Discriminator_loss:0.7068
#
# EPOCH[256] - STEP[70]
# Generator_loss:3.3108
# L1_loss:0.1197
# Discriminator_loss:0.1384
#
# EPOCH[256] - STEP[80]
# Generator_loss:2.8334
# L1_loss:0.1285
# Discriminator_loss:0.1990
#
# EPOCH[256] - STEP[90]
# Generator_loss:6.3357
# L1_loss:0.1034
# Discriminator_loss:0.0067
#
# EPOCH[256] - STEP[100]
# Generator_loss:10.4383
# L1_loss:0.1079
# Discriminator_loss:1.8949
#
# EPOCH[256] - STEP[110]
# Generator_loss:2.6333
# L1_loss:0.1081
# Discriminator_loss:0.1877
#
# EPOCH[256] - STEP[120]
# Generator_loss:3.2900
# L1_loss:0.1130
# Discriminator_loss:0.2939
#
# EPOCH[256] - STEP[130]
# Generator_loss:3.3023
# L1_loss:0.1120
# Discriminator_loss:0.1026
#
# EPOCH[256] - STEP[140]
# Generator_loss:8.1212
# L1_loss:0.1317
# Discriminator_loss:0.0550
#
# EPOCH[256] - STEP[150]
# Generator_loss:5.7741
# L1_loss:0.1211
# Discriminator_loss:0.0256
#
# EPOCH[256] - STEP[160]
# Generator_loss:5.0433
# L1_loss:0.1423
# Discriminator_loss:0.0926
#
# EPOCH[256] - STEP[170]
# Generator_loss:8.0801
# L1_loss:0.1288
# Discriminator_loss:0.0305
#
# EPOCH[256] - STEP[180]
# Generator_loss:0.4065
# L1_loss:0.1256
# Discriminator_loss:1.6188
#
# EPOCH[256] - STEP[190]
# Generator_loss:1.7653
# L1_loss:0.1187
# Discriminator_loss:0.6735
#
# EPOCH[256] - STEP[200]
# Generator_loss:2.9511
# L1_loss:0.1008
# Discriminator_loss:0.1117
#
# EPOCH[256] - STEP[210]
# Generator_loss:2.6985
# L1_loss:0.0989
# Discriminator_loss:0.1738
#
# EPOCH[256] - STEP[220]
# Generator_loss:3.7765
# L1_loss:0.1203
# Discriminator_loss:0.3472
#
# EPOCH[256] - STEP[230]
# Generator_loss:6.7123
# L1_loss:0.1368
# Discriminator_loss:0.0837
#
# EPOCH[256] - STEP[240]
# Generator_loss:4.3904
# L1_loss:0.1211
# Discriminator_loss:0.0495
#
# EPOCH[256] - STEP[250]
# Generator_loss:7.4221
# L1_loss:0.1188
# Discriminator_loss:0.0085

# %% [markdown]
# ## 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
colored, sketch = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
