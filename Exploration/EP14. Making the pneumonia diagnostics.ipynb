# %% [markdown]
# ## 1. Set-up

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %%
# 필요한 변수 생성
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
BATCH_SIZE = 64

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 50

print(ROOT_PATH)
# Out:
# /home/aiffel/aiffel

# %% [markdown]
# ## 2. 데이터 준비

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames)) # val 데이터셋의 수가 너무 적다.
# Out:
# 5216
# 624
# 16

# %%
#  train : val를 80:20으로 분할

filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
# train 데이터 안의 정상 이미지 수와 폐렴 이미지 수 확인

COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1082
# Pneumonia images count in training set: 3103

# %%
# tf.data 인스턴스 만들기

train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
# Train 데이터 셋, validation 데이터 셋 갯수 확인

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 라벨 이름 확인

CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# ['NORMAL' 'PNEUMONIA']

# %%
# 라벨 데이터를 만들어 주는 함수 만들기

def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

# %%
#  이미지의 데이터 타입을 float으로 바꾸고 사이즈를 변경

def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
# train 데이터 셋과 validation 데이터 셋 만들기

train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
# 이미지 및 라벨 확인
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
# test 셋 만들기
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
# augmentation 추가

def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ## 3. 데이터 시각화

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(6,5,n+2)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## 4. CNN 모델링

# %%
# conv_block 만들기

def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
# dense_block 만들기
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ## 5. 데이터 imbalance 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.93
# Weight for class 1: 0.67

# %% [markdown]
# ## 6. 모델 훈련

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
# 모델 fit
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/50
# 65/65 [==============================] - 39s 594ms/step - loss: 0.3992 - accuracy: 0.7974 - precision: 0.9542 - recall: 0.7634 - val_loss: 0.5708 - val_accuracy: 0.7441 - val_precision: 0.7441 - val_recall: 1.0000
# Epoch 2/50
# 65/65 [==============================] - 34s 530ms/step - loss: 0.2012 - accuracy: 0.9224 - precision: 0.9792 - recall: 0.9146 - val_loss: 0.6698 - val_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 3/50
# 65/65 [==============================] - 36s 555ms/step - loss: 0.1573 - accuracy: 0.9411 - precision: 0.9801 - recall: 0.9398 - val_loss: 0.8286 - val_accuracy: 0.7451 - val_precision: 0.7451 - val_recall: 1.0000
# Epoch 4/50
# 65/65 [==============================] - 34s 522ms/step - loss: 0.1523 - accuracy: 0.9481 - precision: 0.9819 - recall: 0.9475 - val_loss: 0.9469 - val_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 5/50
# 65/65 [==============================] - 34s 522ms/step - loss: 0.1412 - accuracy: 0.9478 - precision: 0.9799 - recall: 0.9490 - val_loss: 1.1080 - val_accuracy: 0.7461 - val_precision: 0.7461 - val_recall: 1.0000
# Epoch 6/50
# 65/65 [==============================] - 35s 544ms/step - loss: 0.1238 - accuracy: 0.9538 - precision: 0.9846 - recall: 0.9527 - val_loss: 1.3425 - val_accuracy: 0.7441 - val_precision: 0.7441 - val_recall: 1.0000
# Epoch 7/50
# 65/65 [==============================] - 36s 552ms/step - loss: 0.1165 - accuracy: 0.9548 - precision: 0.9853 - recall: 0.9534 - val_loss: 1.4365 - val_accuracy: 0.7432 - val_precision: 0.7432 - val_recall: 1.0000
# Epoch 8/50
# 65/65 [==============================] - 33s 515ms/step - loss: 0.1105 - accuracy: 0.9594 - precision: 0.9828 - recall: 0.9620 - val_loss: 1.7471 - val_accuracy: 0.7441 - val_precision: 0.7441 - val_recall: 1.0000
# Epoch 9/50
# 65/65 [==============================] - 32s 498ms/step - loss: 0.1068 - accuracy: 0.9644 - precision: 0.9877 - recall: 0.9640 - val_loss: 1.5864 - val_accuracy: 0.7451 - val_precision: 0.7451 - val_recall: 1.0000
# Epoch 10/50
# 65/65 [==============================] - 34s 524ms/step - loss: 0.0904 - accuracy: 0.9688 - precision: 0.9884 - recall: 0.9691 - val_loss: 1.5214 - val_accuracy: 0.7441 - val_precision: 0.7441 - val_recall: 1.0000
# Epoch 11/50
# 65/65 [==============================] - 32s 500ms/step - loss: 0.0972 - accuracy: 0.9656 - precision: 0.9881 - recall: 0.9654 - val_loss: 1.3789 - val_accuracy: 0.7461 - val_precision: 0.7461 - val_recall: 1.0000
# Epoch 12/50
# 65/65 [==============================] - 35s 537ms/step - loss: 0.0930 - accuracy: 0.9647 - precision: 0.9886 - recall: 0.9632 - val_loss: 0.4720 - val_accuracy: 0.8291 - val_precision: 0.8134 - val_recall: 1.0000
# Epoch 13/50
# 65/65 [==============================] - 33s 513ms/step - loss: 0.0756 - accuracy: 0.9716 - precision: 0.9901 - recall: 0.9716 - val_loss: 0.1334 - val_accuracy: 0.9375 - val_precision: 0.9256 - val_recall: 0.9961
# Epoch 14/50
# 65/65 [==============================] - 32s 499ms/step - loss: 0.0800 - accuracy: 0.9716 - precision: 0.9904 - recall: 0.9711 - val_loss: 0.0752 - val_accuracy: 0.9717 - val_precision: 0.9855 - val_recall: 0.9764
# Epoch 15/50
# 65/65 [==============================] - 35s 542ms/step - loss: 0.0734 - accuracy: 0.9721 - precision: 0.9927 - recall: 0.9695 - val_loss: 0.0456 - val_accuracy: 0.9814 - val_precision: 0.9881 - val_recall: 0.9868
# Epoch 16/50
# 65/65 [==============================] - 34s 516ms/step - loss: 0.0713 - accuracy: 0.9762 - precision: 0.9905 - recall: 0.9774 - val_loss: 0.1108 - val_accuracy: 0.9707 - val_precision: 0.9986 - val_recall: 0.9621
# Epoch 17/50
# 65/65 [==============================] - 33s 514ms/step - loss: 0.0803 - accuracy: 0.9738 - precision: 0.9921 - recall: 0.9724 - val_loss: 0.3555 - val_accuracy: 0.8926 - val_precision: 1.0000 - val_recall: 0.8558
# Epoch 18/50
# 65/65 [==============================] - 33s 507ms/step - loss: 0.0648 - accuracy: 0.9767 - precision: 0.9934 - recall: 0.9749 - val_loss: 0.1830 - val_accuracy: 0.9453 - val_precision: 0.9972 - val_recall: 0.9290
# Epoch 19/50
# 65/65 [==============================] - 34s 523ms/step - loss: 0.0545 - accuracy: 0.9808 - precision: 0.9928 - recall: 0.9813 - val_loss: 0.0662 - val_accuracy: 0.9795 - val_precision: 0.9781 - val_recall: 0.9948
# Epoch 20/50
# 65/65 [==============================] - 31s 482ms/step - loss: 0.0652 - accuracy: 0.9748 - precision: 0.9917 - recall: 0.9740 - val_loss: 0.0552 - val_accuracy: 0.9824 - val_precision: 0.9882 - val_recall: 0.9882
# Epoch 21/50
# 65/65 [==============================] - 35s 533ms/step - loss: 0.0699 - accuracy: 0.9752 - precision: 0.9908 - recall: 0.9758 - val_loss: 0.2573 - val_accuracy: 0.8975 - val_precision: 0.8791 - val_recall: 0.9987
# Epoch 22/50
# 65/65 [==============================] - 34s 517ms/step - loss: 0.0659 - accuracy: 0.9757 - precision: 0.9917 - recall: 0.9752 - val_loss: 0.2617 - val_accuracy: 0.9268 - val_precision: 1.0000 - val_recall: 0.9013
# Epoch 23/50
# 65/65 [==============================] - 33s 506ms/step - loss: 0.0516 - accuracy: 0.9800 - precision: 0.9937 - recall: 0.9792 - val_loss: 0.0591 - val_accuracy: 0.9824 - val_precision: 0.9908 - val_recall: 0.9856
# Epoch 24/50
# 65/65 [==============================] - 34s 518ms/step - loss: 0.0542 - accuracy: 0.9808 - precision: 0.9941 - recall: 0.9799 - val_loss: 0.1921 - val_accuracy: 0.9541 - val_precision: 1.0000 - val_recall: 0.9386
# Epoch 25/50
# 65/65 [==============================] - 33s 504ms/step - loss: 0.0465 - accuracy: 0.9829 - precision: 0.9947 - recall: 0.9822 - val_loss: 0.0506 - val_accuracy: 0.9834 - val_precision: 0.9844 - val_recall: 0.9935
# Epoch 26/50
# 65/65 [==============================] - 33s 506ms/step - loss: 0.0417 - accuracy: 0.9832 - precision: 0.9951 - recall: 0.9822 - val_loss: 0.4949 - val_accuracy: 0.8701 - val_precision: 1.0000 - val_recall: 0.8255
# Epoch 27/50
# 65/65 [==============================] - 33s 505ms/step - loss: 0.0325 - accuracy: 0.9858 - precision: 0.9951 - recall: 0.9857 - val_loss: 0.0601 - val_accuracy: 0.9805 - val_precision: 0.9818 - val_recall: 0.9921
# Epoch 28/50
# 65/65 [==============================] - 33s 512ms/step - loss: 0.0286 - accuracy: 0.9887 - precision: 0.9980 - recall: 0.9868 - val_loss: 0.0587 - val_accuracy: 0.9824 - val_precision: 0.9947 - val_recall: 0.9817
# Epoch 29/50
# 65/65 [==============================] - 32s 490ms/step - loss: 0.0409 - accuracy: 0.9844 - precision: 0.9954 - recall: 0.9835 - val_loss: 0.1328 - val_accuracy: 0.9688 - val_precision: 0.9959 - val_recall: 0.9619
# Epoch 30/50
# 65/65 [==============================] - 34s 524ms/step - loss: 0.0472 - accuracy: 0.9839 - precision: 0.9947 - recall: 0.9834 - val_loss: 0.0836 - val_accuracy: 0.9727 - val_precision: 0.9946 - val_recall: 0.9685
# Epoch 31/50
# 65/65 [==============================] - 33s 506ms/step - loss: 0.0453 - accuracy: 0.9856 - precision: 0.9954 - recall: 0.9851 - val_loss: 0.3188 - val_accuracy: 0.9141 - val_precision: 1.0000 - val_recall: 0.8848
# Epoch 32/50
# 65/65 [==============================] - 33s 513ms/step - loss: 0.0462 - accuracy: 0.9820 - precision: 0.9944 - recall: 0.9812 - val_loss: 0.1179 - val_accuracy: 0.9609 - val_precision: 0.9959 - val_recall: 0.9513
# Epoch 33/50
# 65/65 [==============================] - 32s 495ms/step - loss: 0.0301 - accuracy: 0.9911 - precision: 0.9977 - recall: 0.9903 - val_loss: 0.4108 - val_accuracy: 0.9023 - val_precision: 1.0000 - val_recall: 0.8688
# Epoch 34/50
# 65/65 [==============================] - 34s 523ms/step - loss: 0.0434 - accuracy: 0.9827 - precision: 0.9941 - recall: 0.9824 - val_loss: 0.1348 - val_accuracy: 0.9600 - val_precision: 0.9986 - val_recall: 0.9475
# Epoch 35/50
# 65/65 [==============================] - 35s 544ms/step - loss: 0.0401 - accuracy: 0.9856 - precision: 0.9948 - recall: 0.9857 - val_loss: 0.6544 - val_accuracy: 0.8594 - val_precision: 1.0000 - val_recall: 0.8118
# Epoch 36/50
# 65/65 [==============================] - 34s 522ms/step - loss: 0.0557 - accuracy: 0.9810 - precision: 0.9938 - recall: 0.9806 - val_loss: 0.1629 - val_accuracy: 0.9541 - val_precision: 0.9986 - val_recall: 0.9397
# Epoch 37/50
# 65/65 [==============================] - 36s 552ms/step - loss: 0.0421 - accuracy: 0.9825 - precision: 0.9957 - recall: 0.9806 - val_loss: 0.1368 - val_accuracy: 0.9678 - val_precision: 0.9959 - val_recall: 0.9607
# Epoch 38/50
# 65/65 [==============================] - 33s 515ms/step - loss: 0.0382 - accuracy: 0.9865 - precision: 0.9951 - recall: 0.9867 - val_loss: 0.0818 - val_accuracy: 0.9785 - val_precision: 0.9907 - val_recall: 0.9804
# Epoch 39/50
# 65/65 [==============================] - 34s 529ms/step - loss: 0.0330 - accuracy: 0.9863 - precision: 0.9961 - recall: 0.9855 - val_loss: 0.2183 - val_accuracy: 0.9492 - val_precision: 1.0000 - val_recall: 0.9319
# Epoch 40/50
# 65/65 [==============================] - 34s 519ms/step - loss: 0.0288 - accuracy: 0.9894 - precision: 0.9971 - recall: 0.9886 - val_loss: 0.2399 - val_accuracy: 0.9453 - val_precision: 0.9986 - val_recall: 0.9277
# Epoch 41/50
# 65/65 [==============================] - 33s 509ms/step - loss: 0.0361 - accuracy: 0.9870 - precision: 0.9954 - recall: 0.9871 - val_loss: 0.0779 - val_accuracy: 0.9775 - val_precision: 0.9920 - val_recall: 0.9777
# Epoch 42/50
# 65/65 [==============================] - 34s 515ms/step - loss: 0.0348 - accuracy: 0.9863 - precision: 0.9957 - recall: 0.9857 - val_loss: 0.0812 - val_accuracy: 0.9736 - val_precision: 0.9893 - val_recall: 0.9751
# Epoch 43/50
# 65/65 [==============================] - 33s 502ms/step - loss: 0.0326 - accuracy: 0.9861 - precision: 0.9961 - recall: 0.9851 - val_loss: 0.1853 - val_accuracy: 0.9521 - val_precision: 0.9986 - val_recall: 0.9371
# Epoch 44/50
# 65/65 [==============================] - 34s 517ms/step - loss: 0.0200 - accuracy: 0.9918 - precision: 0.9977 - recall: 0.9913 - val_loss: 0.0935 - val_accuracy: 0.9707 - val_precision: 0.9656 - val_recall: 0.9961
# Epoch 45/50
# 65/65 [==============================] - 33s 508ms/step - loss: 0.0325 - accuracy: 0.9875 - precision: 0.9957 - recall: 0.9872 - val_loss: 0.0573 - val_accuracy: 0.9785 - val_precision: 0.9844 - val_recall: 0.9869
# Epoch 46/50
# 65/65 [==============================] - 34s 525ms/step - loss: 0.0412 - accuracy: 0.9825 - precision: 0.9954 - recall: 0.9810 - val_loss: 0.1906 - val_accuracy: 0.9492 - val_precision: 1.0000 - val_recall: 0.9315
# Epoch 47/50
# 65/65 [==============================] - 32s 499ms/step - loss: 0.0402 - accuracy: 0.9865 - precision: 0.9951 - recall: 0.9867 - val_loss: 0.2862 - val_accuracy: 0.9229 - val_precision: 1.0000 - val_recall: 0.8958
# Epoch 48/50
# 65/65 [==============================] - 35s 532ms/step - loss: 0.0380 - accuracy: 0.9834 - precision: 0.9970 - recall: 0.9805 - val_loss: 0.1040 - val_accuracy: 0.9736 - val_precision: 0.9960 - val_recall: 0.9685
# Epoch 49/50
# 65/65 [==============================] - 34s 517ms/step - loss: 0.0274 - accuracy: 0.9892 - precision: 0.9971 - recall: 0.9884 - val_loss: 0.0707 - val_accuracy: 0.9795 - val_precision: 0.9934 - val_recall: 0.9790
# Epoch 50/50
# 65/65 [==============================] - 32s 498ms/step - loss: 0.0224 - accuracy: 0.9918 - precision: 0.9971 - recall: 0.9919 - val_loss: 0.2933 - val_accuracy: 0.9404 - val_precision: 1.0000 - val_recall: 0.9201

# %% [markdown]
# ## 7. 결과 확인과 시각화

# %%
# 시각화

fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
# 모델 평가
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 10/10 [==============================] - 23s 2s/step - loss: 0.5448 - accuracy: 0.8782 - precision: 0.8601 - recall: 0.9615
