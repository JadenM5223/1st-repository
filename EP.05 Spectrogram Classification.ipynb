# %% [markdown]
# # Spectrogram classification 모델 구현

# %% [markdown]
# ## 1. 데이터 처리 & 분류

# %%
import numpy as np
import os

data_path = os.getenv("HOME")+'/aiffel/speech_recognition/data/speech_wav_8000.npz'
speech_data = np.load(data_path)

print("✅")
# Out:
# ✅

# %%
import IPython.display as ipd
import random

# 데이터 선택 (랜덤하게 선택하고 있으니, 여러번 실행해 보세요)
rand = random.randint(0, len(speech_data["wav_vals"]))
print("rand num : ", rand)

sr = 8000 # 1초동안 재생되는 샘플의 갯수
data = speech_data["wav_vals"][rand]
print("Wave data shape : ", data.shape)
print("label : ", speech_data["label_vals"][rand])

ipd.Audio(data, rate=sr)
# Out:
# rand num :  19969
# Wave data shape :  (8000,)
# label :  ['yes']
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Spectrogram으로 변환

# %%
import librosa

def wav2spec(wav, fft_size=258): # spectrogram shape을 맞추기위해서 size 변형
    D = np.abs(librosa.stft(wav, n_fft=fft_size))
    return D
print("✅")
# Out:
# ✅

# %%
# 위에서 뽑았던 sample data
spec = wav2spec(data)
print("Waveform shape : ",data.shape)
print("Spectrogram shape : ",spec.shape)
# Out:
# Waveform shape :  (8000,)
# Spectrogram shape :  (130, 126)

# %%
import matplotlib.pyplot as plt
import librosa.display

librosa.display.specshow(librosa.amplitude_to_db(spec, ref=np.max), x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.xticks(range(0, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Label 데이터 처리

# %%
target_list = ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']

label_value = target_list
label_value.append('unknown')
label_value.append('silence')

print('LABEL : ', label_value)

new_label_value = dict()
for i, l in enumerate(label_value):
    new_label_value[l] = i
label_value = new_label_value

print('Indexed LABEL : ', new_label_value)
# Out:
# LABEL :  ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go', 'unknown', 'silence']
# Indexed LABEL :  {'yes': 0, 'no': 1, 'up': 2, 'down': 3, 'left': 4, 'right': 5, 'on': 6, 'off': 7, 'stop': 8, 'go': 9, 'unknown': 10, 'silence': 11}

# %%
temp = []
for v in speech_data["label_vals"]:
    temp.append(label_value[v[0]])
label_data = np.array(temp)

label_data
# Out:
# array([ 3,  3,  3, ..., 11, 11, 11])

# %% [markdown]
# ### Train, Test 데이터 분리

# %%
from sklearn.model_selection import train_test_split

sr = 8000
train_wav, test_wav, train_label, test_label = train_test_split(speech_data["wav_vals"], 
                                                                label_data, 
                                                                test_size=0.1,
                                                                shuffle=True)
print(train_wav)

train_wav = train_wav.reshape([-1, sr, 1]) # add channel for CNN
test_wav = test_wav.reshape([-1, sr, 1])
print("✅")
# Out:
# [[ 2.5925282e-04 -1.2561034e-03 -7.2872266e-04 ... -2.0419655e-03
#   -1.8097189e-03 -1.0504584e-03]
#  [ 3.1009461e-03  4.4542025e-03 -1.1797669e-04 ...  2.5539068e-03
#    1.8291718e-03 -2.2366510e-03]
#  [-2.8030081e-05 -8.2147133e-05 -2.8990050e-06 ...  1.7768491e-04
#    2.2874776e-05 -1.9373542e-04]
#  ...
#  [ 3.3332829e-03  4.7166995e-03  1.5346384e-05 ...  2.7411019e-03
#    2.2408236e-03 -1.7165879e-03]
#  [-1.4073261e-03 -2.6954559e-03 -2.7082292e-03 ... -2.3786048e-03
#   -2.9828665e-03 -3.3564684e-03]
#  [-6.1583625e-05 -4.6066965e-05 -5.5641856e-05 ...  1.2789575e-04
#    1.2452368e-04  5.4417658e-05]]
# ✅

# %%
print("train data : ", train_wav.shape)
print("train labels : ", train_label.shape)
print("test data : ", test_wav.shape)
print("test labels : ", test_label.shape)
print("✅")
# Out:
# train data :  (45558, 8000, 1)
# train labels :  (45558,)
# test data :  (5062, 8000, 1)
# test labels :  (5062,)
# ✅

# %% [markdown]
# ## 2. Hyper-parameters 세팅

# %%
batch_size = 32
max_epochs = 10

# the save point
checkpoint_dir = os.getenv('HOME')+'/aiffel/speech_recognition/models/wav'

checkpoint_dir
# Out:
# '/home/aiffel/aiffel/speech_recognition/models/wav'

# %%
def one_hot_label(wav, label):
    label = tf.one_hot(label, depth=12)
    return wav, label
print("✅")
# Out:
# ✅

# %%
import tensorflow as tf

# for train
train_dataset = tf.data.Dataset.from_tensor_slices((train_wav, train_label))
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((test_wav, test_label))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)
print(test_dataset)
print("✅")
# Out:
# <BatchDataset shapes: ((None, 8000, 1), (None, 12)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 8000, 1), (None, 12)), types: (tf.float32, tf.float32)>
# ✅

# %% [markdown]
# ## 3. 데이터셋 구성

# %% [markdown]
# ## Wave classification 모델

# %%
from tensorflow.keras import layers

input_tensor = layers.Input(shape=(sr, 1))

x = layers.Conv1D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv1D(32, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)

x = layers.Conv1D(64, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(64, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)

x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)

x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.MaxPool1D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

model_wav = tf.keras.Model(input_tensor, output_tensor)

model_wav.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8000, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 8000, 32)          320
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 8000, 32)          9248
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 4000, 32)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 4000, 64)          18496
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 4000, 64)          36928
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 2000, 64)          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 2000, 128)         73856
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 2000, 128)         147584
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 2000, 128)         147584
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 1000, 128)         0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 1000, 256)         295168
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1000, 256)         590080
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 1000, 256)         590080
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 500, 256)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 500, 256)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 128000)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               32768256
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                3084
# =================================================================
# Total params: 34,681,708
# Trainable params: 34,681,196
# Non-trainable params: 512
# _________________________________________________________________

# %% [markdown]
# ### Loss

# %%
optimizer=tf.keras.optimizers.Adam(1e-4)
model_wav.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
             optimizer=optimizer,
             metrics=['accuracy'])
print("✅")
# Out:
# ✅

# %% [markdown]
# ### Traing

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)
print("✅")
# Out:
# ✅

# %%
#30분 내외 소요 (메모리 사용량에 주의해 주세요.)
history_wav = model_wav.fit(train_dataset, epochs=max_epochs,
                    steps_per_epoch=len(train_wav) // batch_size,
                    validation_data=test_dataset,
                    validation_steps=len(test_wav) // batch_size,
                    callbacks=[cp_callback]
                    )
print("✅")
# Out:
# Epoch 1/10
# 1423/1423 [==============================] - ETA: 0s - loss: 1.4879 - accuracy: 0.4980
# Epoch 00001: val_loss improved from inf to 1.09374, saving model to /home/aiffel/aiffel/speech_recognition/models/wav
# 1423/1423 [==============================] - 169s 119ms/step - loss: 1.4879 - accuracy: 0.4980 - val_loss: 1.0937 - val_accuracy: 0.6377
# Epoch 2/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.8040 - accuracy: 0.7532
# Epoch 00002: val_loss improved from 1.09374 to 0.66145, saving model to /home/aiffel/aiffel/speech_recognition/models/wav
# 1423/1423 [==============================] - 172s 121ms/step - loss: 0.8040 - accuracy: 0.7532 - val_loss: 0.6614 - val_accuracy: 0.7820
# Epoch 3/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.5269 - accuracy: 0.8414
# Epoch 00003: val_loss improved from 0.66145 to 0.43742, saving model to /home/aiffel/aiffel/speech_recognition/models/wav
# 1423/1423 [==============================] - 172s 121ms/step - loss: 0.5269 - accuracy: 0.8414 - val_loss: 0.4374 - val_accuracy: 0.8614
# Epoch 4/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.3555 - accuracy: 0.8998
# Epoch 00004: val_loss improved from 0.43742 to 0.35301, saving model to /home/aiffel/aiffel/speech_recognition/models/wav
# 1423/1423 [==============================] - 173s 121ms/step - loss: 0.3555 - accuracy: 0.8998 - val_loss: 0.3530 - val_accuracy: 0.8875
# Epoch 5/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9375
# Epoch 00005: val_loss improved from 0.35301 to 0.33587, saving model to /home/aiffel/aiffel/speech_recognition/models/wav
# 1423/1423 [==============================] - 173s 122ms/step - loss: 0.2424 - accuracy: 0.9375 - val_loss: 0.3359 - val_accuracy: 0.8944
# Epoch 6/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9575
# Epoch 00006: val_loss improved from 0.33587 to 0.30576, saving model to /home/aiffel/aiffel/speech_recognition/models/wav
# 1423/1423 [==============================] - 173s 122ms/step - loss: 0.1708 - accuracy: 0.9575 - val_loss: 0.3058 - val_accuracy: 0.9055
# Epoch 7/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.9722
# Epoch 00007: val_loss improved from 0.30576 to 0.25167, saving model to /home/aiffel/aiffel/speech_recognition/models/wav
# 1423/1423 [==============================] - 174s 122ms/step - loss: 0.1203 - accuracy: 0.9722 - val_loss: 0.2517 - val_accuracy: 0.9213
# Epoch 8/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.9787
# Epoch 00008: val_loss did not improve from 0.25167
# 1423/1423 [==============================] - 179s 125ms/step - loss: 0.0930 - accuracy: 0.9787 - val_loss: 0.2859 - val_accuracy: 0.9074
# Epoch 9/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9832
# Epoch 00009: val_loss did not improve from 0.25167
# 1423/1423 [==============================] - 184s 129ms/step - loss: 0.0737 - accuracy: 0.9832 - val_loss: 0.2939 - val_accuracy: 0.9061
# Epoch 10/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.9861
# Epoch 00010: val_loss did not improve from 0.25167
# 1423/1423 [==============================] - 172s 121ms/step - loss: 0.0601 - accuracy: 0.9861 - val_loss: 0.2968 - val_accuracy: 0.9070
# ✅

# %% [markdown]
# ## 4. 2차원 Spectrogram 데이터를 처리하는 모델 구성

# %% [markdown]
# ## 5. 학습이 어떻게 진행됐는지 그래프로 출력

# %%
import matplotlib.pyplot as plt

acc = history_wav.history['accuracy']
val_acc = history_wav.history['val_accuracy']

loss=history_wav.history['loss']
val_loss=history_wav.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
print("✅")
# Out:
# ✅

# %% [markdown]
# ## Test 데이터셋을 이용해서 모델 성능 평가

# %% [markdown]
# ### weigh 불러오기

# %%
model_wav.load_weights(checkpoint_dir)
print("✅")
# Out:
# ✅

# %% [markdown]
# ### 모델의 예측값과 정답값이 얼마나 일치하는지 확인

# %%
results = model_wav.evaluate(test_dataset)
print("✅")
# Out:
# 159/159 [==============================] - 19s 120ms/step - loss: 0.2515 - accuracy: 0.9214
# ✅

# %%
# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
print("✅")
# Out:
# loss value: 0.251
# accuracy value: 92.1375%
# ✅

# %% [markdown]
# ### 모델 테스트

# %%
inv_label_value = {v: k for k, v in label_value.items()}
batch_index = np.random.choice(len(test_wav), size=1, replace=False)

batch_xs = test_wav[batch_index]
batch_ys = test_label[batch_index]
y_pred_ = model_wav(batch_xs, training=False)

print("label : ", str(inv_label_value[batch_ys[0]]))

ipd.Audio(batch_xs.reshape(8000,), rate=8000)
# Out:
# label :  on
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
if np.argmax(y_pred_) == batch_ys[0]:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]) + '(Correct!)')
else:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]) + '(Incorrect!)')
print("✅")
# Out:
# y_pred: on(Correct!)
# ✅

# %% [markdown]
# ## Skip-Connection 모델

# %%
input_tensor = layers.Input(shape=(sr, 1))

x = layers.Conv1D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv1D(32, 9, padding='same', activation='relu')(x)
skip_1 = layers.MaxPool1D()(x)

x = layers.Conv1D(64, 9, padding='same', activation='relu')(skip_1)
x = layers.Conv1D(64, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_1], -1)
skip_2 = layers.MaxPool1D()(x)

x = layers.Conv1D(128, 9, padding='same', activation='relu')(skip_2)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(128, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_2], -1)
skip_3 = layers.MaxPool1D()(x)

x = layers.Conv1D(256, 9, padding='same', activation='relu')(skip_3)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv1D(256, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_3], -1)
x = layers.MaxPool1D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

model_wav_skip = tf.keras.Model(input_tensor, output_tensor)

model_wav_skip.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 8000, 32)     320         input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 8000, 32)     9248        conv1d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 4000, 32)     0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 4000, 64)     18496       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 4000, 64)     36928       conv1d_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 4000, 96)]   0           conv1d_13[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 2000, 96)     0           tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 2000, 128)    110720      max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 2000, 128)    147584      conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 2000, 128)    147584      conv1d_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_1 (TensorFlo [(None, 2000, 224)]  0           conv1d_16[0][0]
#                                                                  max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 1000, 224)    0           tf_op_layer_concat_1[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1000, 256)    516352      max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1000, 256)    590080      conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 1000, 256)    590080      conv1d_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_2 (TensorFlo [(None, 1000, 480)]  0           conv1d_19[0][0]
#                                                                  max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 500, 480)     0           tf_op_layer_concat_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 500, 480)     0           max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 240000)       0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          61440256    flatten_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256)          1024        dense_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 12)           3084        activation_1[0][0]
# ==================================================================================================
# Total params: 63,611,756
# Trainable params: 63,611,244
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %% [markdown]
# ### Loss

# %%
optimizer=tf.keras.optimizers.Adam(1e-4)
model_wav_skip.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
             optimizer=optimizer,
             metrics=['accuracy'])
print("✅")
# Out:
# ✅

# %% [markdown]
# ### Training

# %%
# the save point
checkpoint_dir = os.getenv('HOME')+'/aiffel/speech_recognition/models/wav_skip'

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)
print("✅")
# Out:
# ✅

# %%
#30분 내외 소요
history_wav_skip = model_wav_skip.fit(train_dataset, epochs=max_epochs,
                    steps_per_epoch=len(train_wav) // batch_size,
                    validation_data=test_dataset,
                    validation_steps=len(test_wav) // batch_size,
                    callbacks=[cp_callback]
                    )
print("✅")
# Out:
# Epoch 1/10
# 1423/1423 [==============================] - ETA: 0s - loss: 1.2342 - accuracy: 0.6042
# Epoch 00001: val_loss improved from inf to 0.84352, saving model to /home/aiffel/aiffel/speech_recognition/models/wav_skip
# 1423/1423 [==============================] - 199s 140ms/step - loss: 1.2342 - accuracy: 0.6042 - val_loss: 0.8435 - val_accuracy: 0.7320
# Epoch 2/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.6457 - accuracy: 0.8120
# Epoch 00002: val_loss improved from 0.84352 to 0.51212, saving model to /home/aiffel/aiffel/speech_recognition/models/wav_skip
# 1423/1423 [==============================] - 208s 146ms/step - loss: 0.6457 - accuracy: 0.8120 - val_loss: 0.5121 - val_accuracy: 0.8455
# Epoch 3/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.3424 - accuracy: 0.9135
# Epoch 00003: val_loss improved from 0.51212 to 0.40703, saving model to /home/aiffel/aiffel/speech_recognition/models/wav_skip
# 1423/1423 [==============================] - 213s 150ms/step - loss: 0.3424 - accuracy: 0.9135 - val_loss: 0.4070 - val_accuracy: 0.8784
# Epoch 4/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9598
# Epoch 00004: val_loss improved from 0.40703 to 0.36868, saving model to /home/aiffel/aiffel/speech_recognition/models/wav_skip
# 1423/1423 [==============================] - 214s 150ms/step - loss: 0.1819 - accuracy: 0.9598 - val_loss: 0.3687 - val_accuracy: 0.8833
# Epoch 5/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9784
# Epoch 00005: val_loss did not improve from 0.36868
# 1423/1423 [==============================] - 214s 151ms/step - loss: 0.1066 - accuracy: 0.9784 - val_loss: 0.4114 - val_accuracy: 0.8778
# Epoch 6/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9860
# Epoch 00006: val_loss improved from 0.36868 to 0.32763, saving model to /home/aiffel/aiffel/speech_recognition/models/wav_skip
# 1423/1423 [==============================] - 214s 150ms/step - loss: 0.0699 - accuracy: 0.9860 - val_loss: 0.3276 - val_accuracy: 0.9072
# Epoch 7/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9892
# Epoch 00007: val_loss improved from 0.32763 to 0.30764, saving model to /home/aiffel/aiffel/speech_recognition/models/wav_skip
# 1423/1423 [==============================] - 214s 151ms/step - loss: 0.0521 - accuracy: 0.9892 - val_loss: 0.3076 - val_accuracy: 0.9106
# Epoch 8/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9921
# Epoch 00008: val_loss improved from 0.30764 to 0.25391, saving model to /home/aiffel/aiffel/speech_recognition/models/wav_skip
# 1423/1423 [==============================] - 221s 155ms/step - loss: 0.0384 - accuracy: 0.9921 - val_loss: 0.2539 - val_accuracy: 0.9217
# Epoch 9/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9939
# Epoch 00009: val_loss did not improve from 0.25391
# 1423/1423 [==============================] - 220s 155ms/step - loss: 0.0314 - accuracy: 0.9939 - val_loss: 0.2791 - val_accuracy: 0.9173
# Epoch 10/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9951
# Epoch 00010: val_loss did not improve from 0.25391
# 1423/1423 [==============================] - 217s 152ms/step - loss: 0.0254 - accuracy: 0.9951 - val_loss: 0.2634 - val_accuracy: 0.9233
# ✅

# %% [markdown]
# ### 그래프로 출력

# %%
import matplotlib.pyplot as plt

acc = history_wav_skip.history['accuracy']
val_acc = history_wav_skip.history['val_accuracy']

loss=history_wav_skip.history['loss']
val_loss=history_wav_skip.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
print("✅")
# Out:
# ✅

# %% [markdown]
# ### 모델 평가 및 테스트

# %%
# Evaluation 

model_wav_skip.load_weights(checkpoint_dir)
results = model_wav_skip.evaluate(test_dataset)

# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
print("✅")
# Out:
# 159/159 [==============================] - 13s 80ms/step - loss: 0.2536 - accuracy: 0.9218
# loss value: 0.254
# accuracy value: 92.1770%
# ✅

# %%
# Test 

inv_label_value = {v: k for k, v in label_value.items()}
batch_index = np.random.choice(len(test_wav), size=1, replace=False)

batch_xs = test_wav[batch_index]
batch_ys = test_label[batch_index]
y_pred_ = model_wav_skip(batch_xs, training=False)

print("label : ", str(inv_label_value[batch_ys[0]]))

ipd.Audio(batch_xs.reshape(8000,), rate=8000)
# Out:
# label :  off
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
if np.argmax(y_pred_) == batch_ys[0]:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]) + '(Correct!)')
else:
    print("y_pred: " + str(inv_label_value[np.argmax(y_pred_)]) + '(Incorrect!)')
print("✅")
# Out:
# y_pred: off(Correct!)
# ✅
